# %%
import catalyst_reader_helper as cr
import matplotlib.pyplot as plt
import numpy as np

# %%
particle_reader = cr.CatalystReader('/data2/ptycho/2020-1/comm_33IDD')

# %%
start_scan = 241
end_scan = 242
scans = particle_reader.read_catalyst_data_range(mrange=(start_scan, end_scan))
# Out:
# Extracting scanId=241
# Done extracting scanId=241

# %%
data = scans[0]['data'][600]
plt.imshow(np.abs(data), vmin=0, vmax=2**15-1)

# %%
positions_real = scans[0]['positions_real']
plt.close()
plt.plot(positions_real[:, 0], positions_real[:,1], marker='o')#, color='mediumvioletred')
plt.plot(positions_real[0, 0], positions_real[0,1], marker='x')
