# %%
import time
import json
import sys
import os
import glob
import re
import logging
import traceback
import csv
import datetime

from collections import deque

from globus_automate_client import (create_flows_client, graphviz_format, state_colors_for_log,
                                    create_action_client,
                                    create_flows_client)
from funcx.sdk.client import FuncXClient
from funcx.serialize import FuncXSerializer

# Flow Service Client ID
CLIENT_ID = "e6c75d97-532a-4c88-b031-8584a319fa3e"

# %%
# Globus Online Endpoints
src_endpoint = 'dd916908-0072-11e7-badc-22000b9a448b' # mona4 #'hostel' #aps/workstation
dest_endpoint = '08925f04-569f-11e7-bef8-22000b9a448b' #'alcf#dtn_theta'

# FuncX endpoint at ThetaGPU (ALCF) and Prisma (APS)
theta_fx_endpoint = 'ef62df54-6d3c-43ff-8f84-c334f3ab3000' #polaris #'5b5de98e-7701-4484-b03c-619a557c5fe6' # theta-ptycho-8w-1n-2cn #'2ab22e1f-4cf1-47e9-a40c-dd8c58b41d73' #theta-ptycho-8w-1n
prisma_fx_endpoint = '37766683-85e2-49df-a1a7-6a070f566022' #mona4 (prisma-ptycho)

# %%
fxc = FuncXClient()

# %%
# FuncX function definition for remote Polaris GPU reconstruction call

def ptycho(**data):
    """Test the ptycho tool"""
    import os
    import subprocess
    import logging
    from subprocess import PIPE

    rec_ngpu = data['rec_ngpu']
    wid = data['wid']
    dataset_name = data['dataset_name']

    log_file_name = "/grand/hp-ptycho/bicer/20210723_workflow-Xu/logs/funcx-ptycho-{}-w{}-g{}.log".format(dataset_name, wid, rec_ngpu)
    logging.basicConfig(filename=log_file_name,
                        filemode='a',
                        format='%(asctime)s %(levelname)s %(message)s',
                        level=logging.INFO,
                        datefmt='%Y-%m-%d %H:%M:%S')

    logging.info("Starting ptycho funcx function.")

    remote_log_file_name = "/grand/hp-ptycho/bicer/20210723_workflow-Xu/logs/tike-wf-{}-w{}-g{}.log".format(dataset_name, wid, rec_ngpu)

    python_path = data['python_path']
    script_path = data['script_path']

    #recon. script parameters
    ifpath = data['ifpath']
    pospath = data['position_path']
    probepath = data['probe_path']
    ofpath = data['ofpath']
    rec_alg = data['rec_alg']
    rec_nmodes = data['rec_nmodes']
    rec_niter = data['rec_niter']
    rec_output_freq = data['rec_output_freq']
    rec_recover_psi = '--recover-psi' if (('rec_recover_psi' in data) and data['rec_recover_psi']) else ''
    rec_recover_probe = '--recover-probe' if (('rec_recover_probe' in data) and data['rec_recover_probe']) else ''
    rec_recover_positions = '--recover-positions' if (('rec_recover_positions' in data) and data['rec_recover_positions']) else ''
    rec_model = data['rec_model']
    rec_use_mpi = '--use-mpi' if (('rec_use_mpi' in data) and data['rec_use_mpi']) else ''
    rec_overwrite = '--overwrite' if (('rec_overwrite' in data) and data['rec_overwrite']) else ''
    rec_auto_pin = '--auto-pin' if (('rec_auto_pin' in data) and data['rec_auto_pin']) else ''
    rec_gpu_id = data['rec_gpu_id']
    rec_log_filename = remote_log_file_name

    try:
        os.mkdir(ofpath)
    except:
        pass

    cmd = f"{python_path} {script_path} --algorithm={rec_alg} --nmodes={rec_nmodes} --niter={rec_niter} --output-freq={rec_output_freq} {rec_recover_psi} {rec_recover_probe} {rec_recover_positions} --model={rec_model} --ngpu={rec_ngpu} {rec_use_mpi} --ifile='{ifpath}' --position-path={pospath} --probe-path={probepath} {rec_overwrite} {rec_auto_pin} --gpu-id={rec_gpu_id} --folder='{ofpath}' --log-file='{rec_log_filename}'"
    logging.info(f"Running command: {cmd}")

    try:
        res = subprocess.run(cmd, stdout=PIPE, stderr=PIPE,
                             shell=True, executable='/bin/bash')
    except:
        pass
    outstr = f"{res.stdout}"
    return outstr

func_ptycho_uuid = fxc.register_function(ptycho)
print(func_ptycho_uuid)
# Out:
# 886bab18-3a28-4860-a9cf-6e6d2b3ca991

# %%
# FuncX function definition for remote DAQ machine directory calls
def get_folder_paths(path):
    import glob
    import re

    return sorted(glob.glob(path, recursive=False),
                key = lambda v : int(re.search(r"(\d+)" , v[len(v)-"".join(reversed(v)).index('/'):]).group(0)))


def get_file_paths(path):
    import glob
    import re

    return sorted(glob.glob(path, recursive=False),
                key = lambda v : int(re.search(r"(\d+)" , v[len(v)-"".join((reversed(v))).index('/'):v.index('.')]).group(0)))

fx_func_get_file_paths_uuid = fxc.register_function(get_file_paths)
fx_func_get_folder_paths_uuid = fxc.register_function(get_folder_paths)
print(fx_func_get_file_paths_uuid)
print(fx_func_get_folder_paths_uuid)
# Out:
# 3c073025-9a96-40e1-82a7-635906a41dec
# d2425d11-ab91-4ccf-b81d-51e3c6958326

# %%
# Local helper functions for keeping track of the active scans
def append_activated_iids(data, csv_path='/home/beams/TBICER/logs/activated_iids.csv'):
    print("adding row to activated: {}".format(data))
    with open(csv_path, 'a', newline='') as f:
        writer = csv.writer(f)
        for row in data:
            writer.writerow([row, datetime.datetime.now()])
            
def read_activated_iids(csv_path='/home/beams/TBICER/logs/activated_iids.csv'):
    vals = []
    with open(csv_path, newline='') as f:
        reader = csv.reader(f)
        for row in reader:
            vals.append(row)
    return vals

# %%
# Globus Automate flow definition (Gladier will cleanup this)

flow_definition = {
  #"definition":{
      "Comment": "Ptychographic reconstruction workflow",
      "StartAt": "Transfer",
      "States": {
        "Transfer": {
          "Comment": "Initial transfer",
          "Type": "Action",
          "ActionUrl": "https://actions.automate.globus.org/transfer/transfer",
          "ActionScope": "https://auth.globus.org/scopes/actions.globus.org/transfer/transfer",
          "Parameters": {
            "source_endpoint_id.$": "$.input.source_endpoint",
            "destination_endpoint_id.$": "$.input.dest_endpoint",
            "transfer_items": [
              {
                "source_path.$": "$.input.source_path",
                "destination_path.$": "$.input.dest_path",
                "recursive": True
              }
            ]
          },
          "ResultPath": "$.Transfer1Result",
          "WaitTime": 14400,
          "Next": "PosTransfer"
        },
        "PosTransfer": {
          "Comment": "Transfer position file",
          "Type": "Action",
          "ActionUrl": "https://actions.automate.globus.org/transfer/transfer",
          "ActionScope": "https://auth.globus.org/scopes/actions.globus.org/transfer/transfer",
          "Parameters": {
            "source_endpoint_id.$": "$.input.source_endpoint",
            "destination_endpoint_id.$": "$.input.dest_endpoint",
            "transfer_items": [
              {
                "source_path.$": "$.input.source_pos_path",
                "destination_path.$": "$.input.dest_pos_path",
                "recursive": False
              }
            ]
          },
          "ResultPath": "$.Transfer1Result",
          "WaitTime": 14400,
          "Next": "Analyze"
        },
        "Analyze": {
          "Comment": "Run a funcX function",
          "Type": "Action",
          #"ActionUrl": "https://api.funcx.org/automate",
            "ActionUrl": "https://automate.funcx.org",
          #"ActionScope": "https://auth.globus.org/scopes/facd7ccc-c5f4-42aa-916b-a0e270e2c2a9/automate2",
            "ActionScope": "https://auth.globus.org/scopes/b3db7e59-a6f1-4947-95c2-59d6b7a70f8c/action_all",
          "Parameters": {
              "tasks": [{
                "endpoint.$": "$.input.fx_ep",
                "function.$": "$.input.fx_id",
                "payload.$": "$.input.params"
            }]
          },
          "ResultPath": "$.AnalyzeResult",
          "WaitTime": 14400,
          "Next": "Transfer2"
        },
        "Transfer2": {
          "Comment": "Return transfer",
          "Type": "Action",
          "ActionUrl": "https://actions.automate.globus.org/transfer/transfer",
          "ActionScope": "https://auth.globus.org/scopes/actions.globus.org/transfer/transfer",
          "Parameters": {
            "source_endpoint_id.$": "$.input.dest_endpoint",
            "destination_endpoint_id.$": "$.input.source_endpoint",
            "transfer_items": [
              {
                "source_path.$": "$.input.result_path",
                "destination_path.$": "$.input.source_result_path",
                "recursive": True #False
              }
            ]
          },
          "ResultPath": "$.Transfer2Result",
          "WaitTime": 14400,
          "End": True
        },
      },
  #},
  #"input_schema": {}
}

# %%
### Create a flow with the above flow definition ###
flows_client = create_flows_client(CLIENT_ID)
#flow = flows_client.deploy_flow(flow_definition, validate_schema=False, title="Simple ptycho data analysis flow")
flow = flows_client.deploy_flow(flow_definition, input_schema={}, title="Simple ptycho data analysis flow")
flow_id = flow['id']
flow_scope = flow['globus_auth_scope']

# %%
dataset_name = "battery"
q1 = deque()
log_file_name = "/home/beams/TBICER/logs/20210723_workflow-Xu/funcx-ptycho-wf-{}.log".format(dataset_name)
logging.basicConfig(filename=log_file_name,
                    filemode='a',
                    format='%(asctime)s %(levelname)s %(message)s',
                    level=logging.INFO,
                    datefmt='%Y-%m-%d %H:%M:%S')

while True:
    
    ### Start of folder generation ###
    src_wf_root_path = '/mnt/micdata2/velociprobe/2021-2/Xu'
    src_input_folder_prefix = "ptycho-test"
    src_input_pos_folder_prefix = "positions"
    src_output_folder_prefix = "wf-recons-test-i100"

    dest_wf_root_path = '/grand/hp-ptycho/bicer/20210723_workflow-Xu'
    dest_input_folder_prefix = "input"
    dest_output_folder_prefix = "output"

    add_larger_than = 999
    
    # Get the activated iids
    activated_iids_rows = read_activated_iids()
    activated_iids = []
    for r in activated_iids_rows:
        activated_iids.append(r[0])

    # Get the remote folders at source input folder
    src_input_folder_paths_regex = f"{src_wf_root_path}/{src_input_folder_prefix}/*"
    print(src_input_folder_paths_regex)
    rid = fxc.run(src_input_folder_paths_regex,
                  endpoint_id=prisma_fx_endpoint,
                  function_id=fx_func_get_folder_paths_uuid)
    while True:
        try:
            time.sleep(1)
            src_input_folder_paths = fxc.get_result(rid)
            print(src_input_folder_paths)
        except KeyboardInterrupt:
            break
        except:
            print("Result is not ready:{}".format(sys.exc_info()[0]))
            continue
        break

    iids = []
    for src_input_folder_path in src_input_folder_paths:
        #print(src_input_folder_path)
        iid = re.findall(r'\d+', src_input_folder_path)
        if int(iid[-1]) > add_larger_than: 
            #print("id is being added:{}".format(int(iid[-1])))
            iids.append(iid[-1])
        else: continue


    # Get the remote folders at source output folder
    src_output_folder_paths_regex = f"{src_wf_root_path}/{src_output_folder_prefix}/*"
    rid = fxc.run(src_output_folder_paths_regex,
                  endpoint_id=prisma_fx_endpoint,
                  function_id=fx_func_get_folder_paths_uuid)
    while True:
        try:
            time.sleep(1)
            ex_src_output_folder_paths = fxc.get_result(rid)
            #print(ex_src_output_folder_paths)
        except KeyboardInterrupt:
            break
        except:
            print("Result is not ready:{}".format(sys.exc_info()[0]))
            continue
        break

    oiids = []
    for ex_src_output_folder_path in ex_src_output_folder_paths:
        oiid = re.findall(r'\d+', ex_src_output_folder_path)
        if int(oiid[-1]) > add_larger_than: 
            #print("id is being added:{}".format(int(oiid[-1])))
            oiids.append(oiid[-1])
        else: continue

    # Find the iids that need to be processed
    diff_iids = []
    for iid in iids:
        if (int(iid)>add_larger_than) and (iid not in oiids) and (iid not in activated_iids): 
            diff_iids.append(iid) # process only these
    
    # If there is no file to be processed sleep 1 second and recheck 
    if(len(diff_iids)==0):
        print("There is no folder to be processed, sleeping 1 secs.")
        time.sleep(1)
        continue
    #print("diff_iids:{}\niids:{}\noiids:{}\nactivated_iids:{}".format(diff_iids, iids, oiids,activated_iids))
    
    
    #print("Creating works for these ids: {}\n".format(diff_iids))
    fsrc_input_folder_paths = []
    src_input_pos_files = []
    src_output_folder_paths = []
    dest_output_folder_paths = []
    dest_input_folder_paths = []
    dest_input_pos_files = []
    iids = []
    for src_input_folder_path in src_input_folder_paths[:-1]:
        #print(src_input_folder_path)
        iid = re.findall(r'\d+', src_input_folder_path)
        #if (int(iid[-1]) <= add_larger_than) or (iid[-1] in oiids): continue
        # Skip if iid is already activated or processed
        if (iid[-1] not in diff_iids): continue
        iids.append(iid[-1])
        fsrc_input_folder_paths.append(src_input_folder_path)
        src_input_pos_files.append(f"{src_wf_root_path}/{src_input_pos_folder_prefix}/fly{iid[-1]}_0.txt")
        src_output_folder_path = f"{src_wf_root_path}/{src_output_folder_prefix}/{iid[-1]}"
        src_output_folder_paths.append(src_output_folder_path)
        dest_input_folder_path = f"{dest_wf_root_path}/{dest_input_folder_prefix}/{iid[-1]}"
        dest_input_folder_paths.append(dest_input_folder_path)
        dest_input_pos_files.append(f"{dest_input_folder_path}/fly{iid[-1]}_0.txt")
        dest_output_folder_path = f"{dest_wf_root_path}/{dest_output_folder_prefix}/{iid[-1]}"
        dest_output_folder_paths.append(dest_output_folder_path)
    src_input_folder_paths = fsrc_input_folder_paths
    #print(len(src_input_folder_paths))
    # src_input_folder_paths: diffraction patterh files to be processed @ APS
    # src_output_folder_paths: folders for reconstrcuted images after processing @ APS
    # dest_input_folder_paths: diffraction patterh files to be processed @ ALCF
    # dest_output_folder_paths: folders for reconstrcuted images after processing @ ALCF

    iids.reverse()
    src_input_folder_paths.reverse()
    src_input_pos_files.reverse()
    src_output_folder_paths.reverse()
    dest_input_folder_paths.reverse()
    dest_input_pos_files.reverse()
    dest_output_folder_paths.reverse()

    for (iid, src_input_folder_path, src_input_pos_file, src_output_folder_path, dest_input_folder_path, dest_input_pos_file, dest_output_folder_path ) in zip(iids, src_input_folder_paths, src_input_pos_files, src_output_folder_paths, dest_input_folder_paths, dest_input_pos_files, dest_output_folder_paths):
        print(f"{iid}: Source input folder: {src_input_folder_path}; Source position file: {src_input_pos_file}; Source output folder: {src_output_folder_path}")
        print(f"Dest. input folder: {dest_input_folder_path}; Dest. position file: {dest_input_pos_file}; Dest. output folder: {dest_output_folder_path}")
        print()
    
    if(len(iids)>0):
        print("diff_iids:{}\niids:{}\noiids:{}".format(diff_iids, iids, oiids))
    ### End of folder generation ###
    
      
    ### Ptycho recon params setting up ###
    script_path = '/home/bicer/projects/tike/scripts/tike-pinned-ptycho-wf.py'
    #python_path = "/home/bicer/projects/tyler/bin/python"
    python_path = "/home/bicer/miniconda3/envs/ptycho/bin/python"

    probe_path = '/grand/hp-ptycho/bicer/20210723_workflow-Xu/probes/velociprobe-probe.npy'

    rec_alg = 'lstsq_grad'
    rec_nmodes = 1
    rec_upd_pos = False
    rec_niter = 100
    rec_output_freq = 20
    rec_recover_psi = True
    rec_recover_probe= True
    rec_recover_positions = False
    rec_model = 'gaussian'
    rec_ngpu = 1
    rec_use_mpi = False
    rec_overwrite = True
    rec_auto_pin = True

    nworkers_per_node = 8

    flow_inputs = []
    gcounter = 0
    for (iid, src_input_folder_path, src_input_pos_file, src_output_folder_path,
         dest_input_folder_path, dest_input_pos_file, dest_output_folder_path ) in zip(iids,
        src_input_folder_paths, src_input_pos_files, src_output_folder_paths,
        dest_input_folder_paths, dest_input_pos_files, dest_output_folder_paths):

        rec_gpu_id = gcounter%nworkers_per_node

        flow_input = {
            "iid" : iid,
            "input": {
                "source_endpoint": f"{src_endpoint}",
                "source_path": f"{src_input_folder_path}/",
                "source_pos_path": f"{src_input_pos_file}",
                "dest_endpoint": dest_endpoint,
                "dest_path": f"{dest_input_folder_path}/",
                "dest_pos_path": dest_input_pos_file,

                "result_path": f"{dest_output_folder_path}",
                "source_result_path": f"{src_output_folder_path}",
                "fx_ep": f"{theta_fx_endpoint}",
                "fx_id": f"{func_ptycho_uuid}",
                "params": {'ifpath': f"{dest_input_folder_path}/fly{iid}_master.h5",
                           'ofpath': f"{dest_output_folder_path}/",
                           'position_path': dest_input_pos_file,
                           'probe_path': probe_path,
                           'script_path': script_path,
                           'python_path': python_path,
                           'rec_alg': rec_alg,
                           'rec_nmodes': rec_nmodes,
                           'rec_upd_pos': rec_upd_pos,
                           'rec_niter': rec_niter,
                           'rec_output_freq': rec_output_freq,
                           'rec_recover_psi': rec_recover_psi,
                           'rec_recover_probe': rec_recover_probe,
                           'rec_recover_positions': rec_recover_positions,
                           'rec_model': rec_model,
                           'rec_ngpu': rec_ngpu,
                           'rec_use_mpi': rec_use_mpi,
                           'rec_overwrite': rec_overwrite,
                           'rec_auto_pin': rec_auto_pin,
                           'rec_gpu_id':rec_gpu_id,
                           'dataset_name': dataset_name,
                           'wid':gcounter}
            }
        }
        gcounter=gcounter+1
        flow_inputs.append(flow_input)
        ### End of parameter setup
    
    for finputs in flow_inputs:
        print("Flow input iid: {}".format(finputs['iid']))
    
    print("Number of flows to be generated: {}".format(len(flow_inputs)))
    
    ### Initiate Flow ###
    nnodes = 2
    nworkers_per_node = 8

    nflows = len(flow_inputs)

    for i in range(nflows):
        flow_action = flows_client.run_flow(flow_id, flow_scope, flow_inputs[i])
        q1.append(flow_action)
        append_activated_iids([flow_inputs[i]['iid']])
        lstr=f"Flow {i} initiated and added to q1: {flow_action['action_id']}"
        logging.info(lstr)
        print(lstr)
# Out:
# /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/*
# Result is not ready:<class 'funcx.utils.errors.TaskPending'>
# Result is not ready:<class 'funcx.utils.errors.TaskPending'>
# ['/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1200', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1201', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1202', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1203', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1204', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1205', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1206', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1207', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1208', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1209', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1210', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1211', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1212', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1213', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1214', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1215', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1216', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1217', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1218', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1219', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1220', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1221', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1222', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1223', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1224', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1225', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1226', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1227', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1228', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1229', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1230', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1231', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1232', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1233', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1234', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1235', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1236', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1237', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1238', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1239', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1240', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1241', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1242', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1243', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1244', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1245', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1246', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1247', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1248', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1249', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1250', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1251', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1252', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1253', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1254', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1255', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1256', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1257', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1258', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1259', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1260', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1261', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1262', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1263', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1264', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1265', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1266', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-te ...
# 1299: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1299; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1299_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1299
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1299; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1299/fly1299_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1299
#
# 1298: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1298; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1298_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1298
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1298; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1298/fly1298_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1298
#
# 1297: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1297; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1297_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1297
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1297; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1297/fly1297_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1297
#
# 1296: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1296; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1296_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1296
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1296; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1296/fly1296_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1296
#
# 1295: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1295; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1295_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1295
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1295; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1295/fly1295_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1295
#
# 1294: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1294; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1294_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1294
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1294; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1294/fly1294_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1294
#
# 1293: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1293; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1293_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1293
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1293; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1293/fly1293_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1293
#
# 1292: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1292; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1292_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1292
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1292; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1292/fly1292_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1292
#
# 1291: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1291; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1291_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1291
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1291; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1291/fly1291_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1291
#
# 1290: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1290; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1290_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1290
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1290; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1290/fly1290_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1290
#
# 1289: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1289; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1289_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1289
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1289; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1289/fly1289_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1289
#
# 1288: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1288; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1288_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1288
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1288; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1288/fly1288_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1288
#
# 1287: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1287; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1287_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1287
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1287; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1287/fly1287_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1287
#
# 1286: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1286; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1286_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1286
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1286; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1286/fly1286_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1286
#
# 1285: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1285; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1285_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1285
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1285; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1285/fly1285_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1285
#
# 1284: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1284; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1284_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1284
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1284; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1284/fly1284_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1284
#
# 1283: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1283; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1283_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1283
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1283; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1283/fly1283_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1283
#
# 1282: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1282; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1282_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1282
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1282; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1282/fly1282_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1282
#
# 1281: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1281; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1281_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1281
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1281; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1281/fly1281_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1281
#
# 1280: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1280; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1280_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1280
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1280; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1280/fly1280_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1280
#
# 1279: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1279; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1279_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1279
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1279; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1279/fly1279_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1279
#
# 1278: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1278; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1278_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1278
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1278; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1278/fly1278_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1278
#
# 1277: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1277; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1277_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1277
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1277; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1277/fly1277_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1277
#
# 1276: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1276; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1276_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1276
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1276; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1276/fly1276_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1276
#
# 1275: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1275; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1275_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1275
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1275; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1275/fly1275_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1275
#
# 1274: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1274; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1274_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1274
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1274; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1274/fly1274_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1274
#
# 1273: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1273; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1273_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1273
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1273; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1273/fly1273_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1273
#
# 1272: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1272; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1272_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1272
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1272; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1272/fly1272_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1272
#
# 1271: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1271; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1271_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1271
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1271; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1271/fly1271_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1271
#
# 1270: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1270; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1270_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1270
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1270; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1270/fly1270_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1270
#
# 1269: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1269; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1269_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1269
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1269; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1269/fly1269_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1269
#
# 1268: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1268; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1268_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1268
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1268; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1268/fly1268_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1268
#
# 1267: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1267; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1267_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1267
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1267; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1267/fly1267_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1267
#
# 1266: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1266; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1266_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1266
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1266; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1266/fly1266_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1266
#
# 1265: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1265; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1265_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1265
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1265; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1265/fly1265_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1265
#
# 1264: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1264; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1264_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1264
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1264; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1264/fly1264_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1264
#
# 1263: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1263; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1263_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1263
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1263; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1263/fly1263_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1263
#
# 1262: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1262; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1262_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1262
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1262; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1262/fly1262_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1262
#
# 1261: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1261; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1261_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1261
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1261; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1261/fly1261_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1261
#
# 1260: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1260; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1260_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1260
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1260; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1260/fly1260_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1260
#
# 1259: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1259; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1259_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1259
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1259; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1259/fly1259_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1259
#
# 1258: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1258; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1258_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1258
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1258; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1258/fly1258_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1258
#
# 1257: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1257; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1257_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1257
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1257; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1257/fly1257_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1257
#
# 1256: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1256; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1256_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1256
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1256; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1256/fly1256_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1256
#
# 1255: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1255; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1255_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1255
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1255; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1255/fly1255_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1255
#
# 1254: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1254; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1254_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1254
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1254; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1254/fly1254_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1254
#
# 1253: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1253; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1253_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1253
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1253; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1253/fly1253_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1253
#
# 1252: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1252; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1252_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1252
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1252; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1252/fly1252_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1252
#
# 1251: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1251; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1251_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1251
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1251; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1251/fly1251_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1251
#
# 1250: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1250; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1250_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1250
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1250; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1250/fly1250_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1250
#
# 1249: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1249; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1249_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1249
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1249; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1249/fly1249_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1249
#
# 1248: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1248; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1248_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1248
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1248; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1248/fly1248_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1248
#
# 1247: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1247; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1247_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1247
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1247; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1247/fly1247_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1247
#
# 1246: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1246; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1246_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1246
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1246; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1246/fly1246_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1246
#
# 1245: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1245; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1245_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1245
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1245; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1245/fly1245_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1245
#
# 1244: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1244; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1244_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1244
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1244; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1244/fly1244_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1244
#
# 1243: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1243; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1243_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1243
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1243; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1243/fly1243_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1243
#
# 1242: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1242; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1242_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1242
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1242; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1242/fly1242_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1242
#
# 1241: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1241; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1241_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1241
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1241; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1241/fly1241_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1241
#
# 1240: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1240; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1240_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1240
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1240; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1240/fly1240_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1240
#
# 1239: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1239; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1239_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1239
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1239; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1239/fly1239_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1239
#
# 1238: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1238; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1238_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1238
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1238; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1238/fly1238_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1238
#
# 1237: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1237; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1237_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1237
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1237; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1237/fly1237_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1237
#
# 1236: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1236; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1236_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1236
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1236; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1236/fly1236_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1236
#
# 1235: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1235; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1235_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1235
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1235; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1235/fly1235_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1235
#
# 1234: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1234; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1234_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1234
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1234; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1234/fly1234_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1234
#
# 1233: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1233; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1233_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1233
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1233; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1233/fly1233_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1233
#
# 1232: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1232; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1232_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1232
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1232; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1232/fly1232_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1232
#
# 1231: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1231; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1231_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1231
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1231; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1231/fly1231_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1231
#
# 1230: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1230; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1230_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1230
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1230; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1230/fly1230_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1230
#
# 1229: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1229; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1229_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1229
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1229; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1229/fly1229_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1229
#
# 1228: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1228; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1228_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1228
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1228; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1228/fly1228_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1228
#
# 1227: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1227; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1227_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1227
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1227; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1227/fly1227_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1227
#
# 1226: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1226; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1226_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1226
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1226; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1226/fly1226_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1226
#
# 1225: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1225; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1225_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1225
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1225; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1225/fly1225_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1225
#
# 1224: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1224; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1224_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1224
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1224; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1224/fly1224_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1224
#
# 1223: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1223; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1223_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1223
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1223; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1223/fly1223_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1223
#
# 1222: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1222; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1222_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1222
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1222; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1222/fly1222_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1222
#
# 1221: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1221; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1221_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1221
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1221; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1221/fly1221_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1221
#
# 1220: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1220; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1220_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1220
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1220; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1220/fly1220_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1220
#
# 1219: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1219; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1219_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1219
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1219; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1219/fly1219_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1219
#
# 1218: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1218; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1218_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1218
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1218; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1218/fly1218_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1218
#
# 1217: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1217; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1217_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1217
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1217; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1217/fly1217_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1217
#
# 1216: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1216; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1216_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1216
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1216; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1216/fly1216_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1216
#
# 1215: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1215; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1215_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1215
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1215; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1215/fly1215_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1215
#
# 1214: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1214; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1214_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1214
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1214; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1214/fly1214_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1214
#
# 1213: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1213; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1213_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1213
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1213; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1213/fly1213_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1213
#
# 1212: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1212; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1212_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1212
# Dest. input folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1212; Dest. position file: /grand/hp-ptycho/bicer/20210723_workflow-Xu/input/1212/fly1212_0.txt; Dest. output folder: /grand/hp-ptycho/bicer/20210723_workflow-Xu/output/1212
#
# 1211: Source input folder: /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1211; Source position file: /mnt/micdata2/velociprobe/2021-2/Xu/positions/fly1211_0.txt; Source output folder: /mnt/micdata2/velociprobe/2021-2/Xu/wf-recons-test-i100/1211
# ...
# Number of flows to be generated: 0
# /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/*
# ['/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1200', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1201', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1202', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1203', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1204', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1205', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1206', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1207', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1208', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1209', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1210', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1211', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1212', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1213', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1214', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1215', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1216', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1217', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1218', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1219', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1220', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1221', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1222', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1223', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1224', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1225', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1226', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1227', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1228', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1229', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1230', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1231', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1232', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1233', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1234', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1235', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1236', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1237', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1238', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1239', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1240', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1241', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1242', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1243', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1244', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1245', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1246', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1247', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1248', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1249', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1250', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1251', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1252', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1253', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1254', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1255', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1256', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1257', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1258', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1259', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1260', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1261', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1262', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1263', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1264', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1265', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1266', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-te ...
# Number of flows to be generated: 0
# /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/*
# ['/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1200', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1201', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1202', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1203', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1204', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1205', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1206', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1207', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1208', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1209', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1210', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1211', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1212', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1213', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1214', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1215', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1216', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1217', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1218', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1219', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1220', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1221', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1222', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1223', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1224', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1225', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1226', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1227', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1228', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1229', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1230', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1231', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1232', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1233', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1234', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1235', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1236', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1237', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1238', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1239', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1240', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1241', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1242', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1243', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1244', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1245', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1246', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1247', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1248', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1249', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1250', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1251', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1252', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1253', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1254', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1255', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1256', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1257', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1258', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1259', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1260', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1261', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1262', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1263', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1264', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1265', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/fly1266', '/mnt/micdata2/velociprobe/2021-2/Xu/ptycho-te ...
# Number of flows to be generated: 0
# /mnt/micdata2/velociprobe/2021-2/Xu/ptycho-test/*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3709766/3382861410.py in <module>
#      31     src_input_folder_paths_regex = f"{src_wf_root_path}/{src_input_folder_prefix}/*"
#      32     print(src_input_folder_paths_regex)
# ---> 33     rid = fxc.run(src_input_folder_paths_regex,
#      34                   endpoint_id=prisma_fx_endpoint,
#      35                   function_id=fx_func_get_folder_paths_uuid)
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/funcx/sdk/client.py in run(self, endpoint_id, function_id, *args, **kwargs)
#     382         batch = self.create_batch()
#     383         batch.add(*args, endpoint_id=endpoint_id, function_id=function_id, **kwargs)
# --> 384         r = self.batch_run(batch)
#     385
#     386         return r[0]
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/funcx/sdk/client.py in batch_run(self, batch)
#     428
#     429         # Send the data to funcX
# --> 430         r = self.post(servable_path, json_body=data)
#     431
#     432         task_uuids = []
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/funcx/sdk/error_handling_client.py in post(self, path, **kwargs)
#      29     def post(self, path, **kwargs):
#      30         try:
# ---> 31             r = ThrottledBaseClient.post(self, path, **kwargs)
#      32         except GlobusAPIError as e:
#      33             handle_response_errors(e.raw_json)
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/globus_sdk/base.py in post(self, path, json_body, params, headers, text_body, response_class, retry_401)
#     253         """
#     254         self.logger.debug(f"POST to {path} with params {params}")
# --> 255         return self._request(
#     256             "POST",
#     257             path,
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/funcx/sdk/utils/throttling.py in _request(self, *args, **kwargs)
#      82             self.throttle_request_size(*args, **kwargs)
#      83             self.throttle_max_requests()
# ---> 84         return super()._request(*args, **kwargs)
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/globus_sdk/base.py in _request(self, method, path, params, headers, json_body, text_body, response_class, retry_401)
#     468
#     469         # initial request
# --> 470         r = send_request()
#     471
#     472         self.logger.debug(f"Request made to URL: {r.url}")
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/globus_sdk/base.py in send_request()
#     454         def send_request():
#     455             try:
# --> 456                 return self._session.request(
#     457                     method=method,
#     458                     url=url,
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/miniconda3/envs/workflow/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/miniconda3/envs/workflow/lib/python3.9/http/client.py in getresponse(self)
#    1347         try:
#    1348             try:
# -> 1349                 response.begin()
#    1350             except ConnectionError:
#    1351                 self.close()
#
# ~/miniconda3/envs/workflow/lib/python3.9/http/client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# ~/miniconda3/envs/workflow/lib/python3.9/http/client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# ~/miniconda3/envs/workflow/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/miniconda3/envs/workflow/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/miniconda3/envs/workflow/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Cancel all flows
for flow_action in q1:
    flows_client.flow_action_cancel(flow_id, flow_scope, flow_action['action_id'])
