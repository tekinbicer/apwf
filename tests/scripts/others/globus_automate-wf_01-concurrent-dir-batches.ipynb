# %%
import time
import json
import sys
import os
import glob
import re
from collections import deque

from globus_automate_client import (create_flows_client, graphviz_format, state_colors_for_log,
                                    create_action_client, 
                                    create_flows_client)
from funcx.sdk.client import FuncXClient
from funcx.serialize import FuncXSerializer

CLIENT_ID = "e6c75d97-532a-4c88-b031-8584a319fa3e"

# %%
fxc = FuncXClient()
# fxs = FuncXSerializer() # (de)serialize the funcx codes

# %%
def ptycho(data):
    """Test the ptycho tool"""
    import os
    import subprocess
    from subprocess import PIPE
    
    python_path = data['python_path']
    script_path = data['script_path']
    
    #recon. script parameters
    ifpath = data['ifpath']
    ofpath = data['ofpath']
    rec_alg = data['rec_alg']
    rec_nmodes = data['rec_nmodes']
    rec_niter = data['rec_niter']
    rec_output_freq = data['rec_output_freq']
    rec_recover_psi = '--recover-psi' if (('rec_recover_psi' in data) and data['rec_recover_psi']) else ''
    rec_recover_probe = '--recover-probe' if (('rec_recover_probe' in data) and data['rec_recover_probe']) else ''
    rec_recover_positions = '--recover-positions' if (('rec_recover_positions' in data) and data['rec_recover_positions']) else ''
    rec_model = data['rec_model']
    rec_ngpu = data['rec_ngpu']
    rec_use_mpi = '--use-mpi' if (('rec_use_mpi' in data) and data['rec_use_mpi']) else ''
    
    try:
        os.mkdir(ofpath)
    except:
        pass
    
    cmd = f"{python_path} {script_path} --algorithm={rec_alg} --nmodes={rec_nmodes} --niter={rec_niter} --output-freq={rec_output_freq} {rec_recover_psi} {rec_recover_probe} {rec_recover_positions} --model={rec_model} --ngpu={rec_ngpu} {rec_use_mpi} --ifile='{ifpath}' --folder='{ofpath}'"

    try:
        res = subprocess.run(cmd, stdout=PIPE, stderr=PIPE,
                             shell=True, executable='/bin/bash')
    except:
        pass
    outstr = f"{res.stdout}"
    return outstr
    
func_ptycho_uuid = fxc.register_function(ptycho)
print(func_ptycho_uuid)
# Out:
# 66113be9-af59-440b-bf3a-b850f4818dcd

# %%
def get_folder_paths(path):
    import glob
    import re
    
    #return f"{path}/teko007"
    return sorted(glob.glob(path, recursive=False),
                key = lambda v : int(re.search(r"(\d+)" , v[len(v)-"".join(reversed(v)).index('/'):]).group(0)))

def get_file_paths(path):
    import glob
    import re
    
    return sorted(glob.glob(path, recursive=False),
                key = lambda v : int(re.search(r"(\d+)" , v[len(v)-"".join((reversed(v))).index('/'):v.index('.')]).group(0)))

fx_func_get_file_paths_uuid = fxc.register_function(get_file_paths)
fx_func_get_folder_paths_uuid = fxc.register_function(get_folder_paths)
print(fx_func_get_file_paths_uuid)
print(fx_func_get_folder_paths_uuid)
# Out:
# 6a2b9010-85a8-4eaa-a50f-235b4415ce53
# 803d5584-57a9-4370-9582-354399dcc233

# %%
def copy_file(params):
    import os
    import shutil
    
    ifpath = params['ifpath']
    ofpath = params['ofpath']
    
    #shutil.copyfile(ifpath, ofpath)
    shutil.copytree(ifpath, ofpath)

def my_hello():
    return "Welcome to the machine"

func_cp_uuid = fxc.register_function(copy_file)
func_hl_uuid = fxc.register_function(my_hello)
print(func_cp_uuid)
# Out:
# 5d61d781-c39b-4d88-b67b-4130f3ec333e

# %%
flow_definition = {
  "Comment": "An analysis flow",
  "StartAt": "Transfer",
  "States": {
    "Transfer": {
      "Comment": "Initial transfer",
      "Type": "Action",
      "ActionUrl": "https://actions.automate.globus.org/transfer/transfer",
      "ActionScope": "https://auth.globus.org/scopes/actions.globus.org/transfer/transfer",
      "Parameters": {
        "source_endpoint_id.$": "$.input.source_endpoint", 
        "destination_endpoint_id.$": "$.input.dest_endpoint",
        "transfer_items": [
          {
            "source_path.$": "$.input.source_path",
            "destination_path.$": "$.input.dest_path",
            "recursive": True
          }
        ]
      },
      "ResultPath": "$.Transfer1Result",
      "WaitTime": 1800,
      "Next": "Analyze"
    },
    "Analyze": {
      "Comment": "Run a funcX function",
      "Type": "Action",
      "ActionUrl": "https://api.funcx.org/automate",
      "ActionScope": "https://auth.globus.org/scopes/facd7ccc-c5f4-42aa-916b-a0e270e2c2a9/automate2",
      "Parameters": {
          "tasks": [{
            "endpoint.$": "$.input.fx_ep",
            "func.$": "$.input.fx_id",
            "payload.$": "$.input.params"
        }]
      },
      "ResultPath": "$.AnalyzeResult",
      "WaitTime": 3600,
      "Next": "Transfer2"
    },
    "Transfer2": {
      "Comment": "Return transfer",
      "Type": "Action",
      "ActionUrl": "https://actions.automate.globus.org/transfer/transfer",
      "ActionScope": "https://auth.globus.org/scopes/actions.globus.org/transfer/transfer",
      "Parameters": {
        "source_endpoint_id.$": "$.input.dest_endpoint", 
        "destination_endpoint_id.$": "$.input.source_endpoint",
        "transfer_items": [
          {
            "source_path.$": "$.input.result_path",
            "destination_path.$": "$.input.source_result_path",
            "recursive": True #False
          }
        ]
      },
      "ResultPath": "$.Transfer2Result",
      "WaitTime": 1800,
      "End": True
    },
  }
}

# %%
prisma_fx_endpoint = '4bf59543-3398-42d2-9416-c628e9f5635f'

src_wf_root_path = '/prisma-data1/bicer/workflow' #'/gdata/RAVEN/bicer/2020-1/comm_33IDD/globus_automate'
src_input_folder_prefix = "input"
src_output_folder_prefix = "output"

dest_wf_root_path = '/grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate'
dest_input_folder_prefix = "input"
dest_output_folder_prefix = "output"


#src_input_folder_paths_regex = f"{src_wf_root_path}/{src_input_folder_prefix}/*.h5"
src_input_folder_paths_regex = f"{src_wf_root_path}/{src_input_folder_prefix}/*"
rid = fxc.run(src_input_folder_paths_regex, 
              endpoint_id=prisma_fx_endpoint, 
              function_id=fx_func_get_folder_paths_uuid)
src_input_folder_paths = fxc.get_result(rid)

src_output_folder_paths = []
dest_output_folder_paths = []
dest_input_folder_paths = []
for src_input_folder_path in src_input_folder_paths:
    #print(src_input_folder_path)
    iid = re.findall(r'\d+', src_input_folder_path)
    src_output_folder_path = f"{src_wf_root_path}/{src_output_folder_prefix}/{iid[-1]}"
    src_output_folder_paths.append(src_output_folder_path)
    dest_input_folder_path = f"{dest_wf_root_path}/{dest_input_folder_prefix}/{iid[-1]}"
    dest_input_folder_paths.append(dest_input_folder_path)
    dest_output_folder_path = f"{dest_wf_root_path}/{dest_output_folder_prefix}/{iid[-1]}"
    dest_output_folder_paths.append(dest_output_folder_path)
    
    

# src_input_folder_paths: diffraction patterh files to be processed @ APS
# src_output_folder_paths: folders for reconstrcuted images after processing @ APS
# dest_input_folder_paths: diffraction patterh files to be processed @ ALCF
# dest_output_folder_paths: folders for reconstrcuted images after processing @ ALCF

for (src_input_folder_path, src_output_folder_path, dest_input_folder_path, dest_output_folder_path ) in zip(src_input_folder_paths, src_output_folder_paths, dest_input_folder_paths, dest_output_folder_paths):
    print(f"Source input folder: {src_input_folder_path}; Source output folder: {src_output_folder_path}")
    print(f"Dest. input folder: {dest_input_folder_path}; Dest. output folder: {dest_output_folder_path}")
    print()
# Out:
# Source input folder: /prisma-data1/bicer/workflow/input/scan192; Source output folder: /prisma-data1/bicer/workflow/output/192
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/192; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/192
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan193; Source output folder: /prisma-data1/bicer/workflow/output/193
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/193; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/193
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan194; Source output folder: /prisma-data1/bicer/workflow/output/194
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/194; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/194
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan195; Source output folder: /prisma-data1/bicer/workflow/output/195
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/195; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/195
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan196; Source output folder: /prisma-data1/bicer/workflow/output/196
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/196; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/196
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan197; Source output folder: /prisma-data1/bicer/workflow/output/197
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/197; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/197
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan199; Source output folder: /prisma-data1/bicer/workflow/output/199
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/199; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/199
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan200; Source output folder: /prisma-data1/bicer/workflow/output/200
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/200; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/200
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan201; Source output folder: /prisma-data1/bicer/workflow/output/201
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/201; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/201
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan202; Source output folder: /prisma-data1/bicer/workflow/output/202
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/202; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/202
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan203; Source output folder: /prisma-data1/bicer/workflow/output/203
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/203; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/203
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan204; Source output folder: /prisma-data1/bicer/workflow/output/204
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/204; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/204
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan205; Source output folder: /prisma-data1/bicer/workflow/output/205
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/205; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/205
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan206; Source output folder: /prisma-data1/bicer/workflow/output/206
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/206; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/206
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan207; Source output folder: /prisma-data1/bicer/workflow/output/207
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/207; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/207
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan208; Source output folder: /prisma-data1/bicer/workflow/output/208
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/208; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/208
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan209; Source output folder: /prisma-data1/bicer/workflow/output/209
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/209; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/209
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan210; Source output folder: /prisma-data1/bicer/workflow/output/210
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/210; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/210
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan211; Source output folder: /prisma-data1/bicer/workflow/output/211
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/211; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/211
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan212; Source output folder: /prisma-data1/bicer/workflow/output/212
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/212; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/212
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan213; Source output folder: /prisma-data1/bicer/workflow/output/213
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/213; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/213
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan214; Source output folder: /prisma-data1/bicer/workflow/output/214
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/214; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/214
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan215; Source output folder: /prisma-data1/bicer/workflow/output/215
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/215; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/215
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan216; Source output folder: /prisma-data1/bicer/workflow/output/216
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/216; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/216
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan217; Source output folder: /prisma-data1/bicer/workflow/output/217
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/217; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/217
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan218; Source output folder: /prisma-data1/bicer/workflow/output/218
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/218; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/218
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan219; Source output folder: /prisma-data1/bicer/workflow/output/219
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/219; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/219
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan220; Source output folder: /prisma-data1/bicer/workflow/output/220
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/220; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/220
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan221; Source output folder: /prisma-data1/bicer/workflow/output/221
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/221; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/221
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan222; Source output folder: /prisma-data1/bicer/workflow/output/222
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/222; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/222
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan223; Source output folder: /prisma-data1/bicer/workflow/output/223
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/223; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/223
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan224; Source output folder: /prisma-data1/bicer/workflow/output/224
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/224; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/224
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan225; Source output folder: /prisma-data1/bicer/workflow/output/225
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/225; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/225
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan226; Source output folder: /prisma-data1/bicer/workflow/output/226
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/226; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/226
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan227; Source output folder: /prisma-data1/bicer/workflow/output/227
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/227; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/227
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan228; Source output folder: /prisma-data1/bicer/workflow/output/228
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/228; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/228
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan229; Source output folder: /prisma-data1/bicer/workflow/output/229
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/229; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/229
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan230; Source output folder: /prisma-data1/bicer/workflow/output/230
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/230; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/230
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan231; Source output folder: /prisma-data1/bicer/workflow/output/231
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/231; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/231
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan232; Source output folder: /prisma-data1/bicer/workflow/output/232
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/232; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/232
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan233; Source output folder: /prisma-data1/bicer/workflow/output/233
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/233; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/233
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan234; Source output folder: /prisma-data1/bicer/workflow/output/234
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/234; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/234
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan235; Source output folder: /prisma-data1/bicer/workflow/output/235
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/235; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/235
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan236; Source output folder: /prisma-data1/bicer/workflow/output/236
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/236; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/236
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan237; Source output folder: /prisma-data1/bicer/workflow/output/237
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/237; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/237
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan238; Source output folder: /prisma-data1/bicer/workflow/output/238
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/238; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/238
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan239; Source output folder: /prisma-data1/bicer/workflow/output/239
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/239; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/239
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan240; Source output folder: /prisma-data1/bicer/workflow/output/240
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/240; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/240
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan241; Source output folder: /prisma-data1/bicer/workflow/output/241
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/241; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/241
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan242; Source output folder: /prisma-data1/bicer/workflow/output/242
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/242; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/242
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan243; Source output folder: /prisma-data1/bicer/workflow/output/243
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/243; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/243
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan244; Source output folder: /prisma-data1/bicer/workflow/output/244
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/244; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/244
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan245; Source output folder: /prisma-data1/bicer/workflow/output/245
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/245; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/245
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan246; Source output folder: /prisma-data1/bicer/workflow/output/246
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/246; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/246
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan247; Source output folder: /prisma-data1/bicer/workflow/output/247
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/247; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/247
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan248; Source output folder: /prisma-data1/bicer/workflow/output/248
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/248; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/248
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan249; Source output folder: /prisma-data1/bicer/workflow/output/249
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/249; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/249
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan250; Source output folder: /prisma-data1/bicer/workflow/output/250
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/250; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/250
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan251; Source output folder: /prisma-data1/bicer/workflow/output/251
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/251; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/251
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan252; Source output folder: /prisma-data1/bicer/workflow/output/252
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/252; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/252
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan253; Source output folder: /prisma-data1/bicer/workflow/output/253
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/253; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/253
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan254; Source output folder: /prisma-data1/bicer/workflow/output/254
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/254; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/254
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan255; Source output folder: /prisma-data1/bicer/workflow/output/255
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/255; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/255
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan256; Source output folder: /prisma-data1/bicer/workflow/output/256
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/256; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/256
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan257; Source output folder: /prisma-data1/bicer/workflow/output/257
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/257; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/257
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan258; Source output folder: /prisma-data1/bicer/workflow/output/258
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/258; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/258
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan259; Source output folder: /prisma-data1/bicer/workflow/output/259
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/259; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/259
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan260; Source output folder: /prisma-data1/bicer/workflow/output/260
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/260; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/260
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan261; Source output folder: /prisma-data1/bicer/workflow/output/261
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/261; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/261
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan262; Source output folder: /prisma-data1/bicer/workflow/output/262
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/262; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/262
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan263; Source output folder: /prisma-data1/bicer/workflow/output/263
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/263; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/263
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan264; Source output folder: /prisma-data1/bicer/workflow/output/264
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/264; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/264
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan265; Source output folder: /prisma-data1/bicer/workflow/output/265
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/265; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/265
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan266; Source output folder: /prisma-data1/bicer/workflow/output/266
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/266; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/266
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan267; Source output folder: /prisma-data1/bicer/workflow/output/267
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/267; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/267
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan268; Source output folder: /prisma-data1/bicer/workflow/output/268
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/268; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/268
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan269; Source output folder: /prisma-data1/bicer/workflow/output/269
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/269; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/269
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan270; Source output folder: /prisma-data1/bicer/workflow/output/270
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/270; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/270
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan271; Source output folder: /prisma-data1/bicer/workflow/output/271
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/271; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/271
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan272; Source output folder: /prisma-data1/bicer/workflow/output/272
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/272; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/272
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan273; Source output folder: /prisma-data1/bicer/workflow/output/273
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/273; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/273
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan274; Source output folder: /prisma-data1/bicer/workflow/output/274
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/274; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/274
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan275; Source output folder: /prisma-data1/bicer/workflow/output/275
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/275; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/275
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan276; Source output folder: /prisma-data1/bicer/workflow/output/276
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/276; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/276
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan277; Source output folder: /prisma-data1/bicer/workflow/output/277
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/277; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/277
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan278; Source output folder: /prisma-data1/bicer/workflow/output/278
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/278; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/278
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan279; Source output folder: /prisma-data1/bicer/workflow/output/279
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/279; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/279
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan280; Source output folder: /prisma-data1/bicer/workflow/output/280
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/280; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/280
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan281; Source output folder: /prisma-data1/bicer/workflow/output/281
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/281; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/281
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan282; Source output folder: /prisma-data1/bicer/workflow/output/282
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/282; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/282
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan283; Source output folder: /prisma-data1/bicer/workflow/output/283
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/283; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/283
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan284; Source output folder: /prisma-data1/bicer/workflow/output/284
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/284; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/284
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan285; Source output folder: /prisma-data1/bicer/workflow/output/285
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/285; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/285
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan286; Source output folder: /prisma-data1/bicer/workflow/output/286
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/286; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/286
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan287; Source output folder: /prisma-data1/bicer/workflow/output/287
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/287; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/287
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan288; Source output folder: /prisma-data1/bicer/workflow/output/288
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/288; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/288
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan289; Source output folder: /prisma-data1/bicer/workflow/output/289
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/289; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/289
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan290; Source output folder: /prisma-data1/bicer/workflow/output/290
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/290; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/290
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan291; Source output folder: /prisma-data1/bicer/workflow/output/291
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/291; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/291
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan292; Source output folder: /prisma-data1/bicer/workflow/output/292
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/292; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/292
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan293; Source output folder: /prisma-data1/bicer/workflow/output/293
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/293; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/293
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan294; Source output folder: /prisma-data1/bicer/workflow/output/294
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/294; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/294
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan295; Source output folder: /prisma-data1/bicer/workflow/output/295
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/295; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/295
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan296; Source output folder: /prisma-data1/bicer/workflow/output/296
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/296; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/296
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan297; Source output folder: /prisma-data1/bicer/workflow/output/297
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/297; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/297
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan298; Source output folder: /prisma-data1/bicer/workflow/output/298
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/298; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/298
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan299; Source output folder: /prisma-data1/bicer/workflow/output/299
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/299; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/299
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan300; Source output folder: /prisma-data1/bicer/workflow/output/300
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/300; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/300
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan301; Source output folder: /prisma-data1/bicer/workflow/output/301
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/301; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/301
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan302; Source output folder: /prisma-data1/bicer/workflow/output/302
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/302; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/302
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan303; Source output folder: /prisma-data1/bicer/workflow/output/303
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/303; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/303
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan304; Source output folder: /prisma-data1/bicer/workflow/output/304
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/304; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/304
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan305; Source output folder: /prisma-data1/bicer/workflow/output/305
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/305; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/305
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan306; Source output folder: /prisma-data1/bicer/workflow/output/306
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/306; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/306
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan307; Source output folder: /prisma-data1/bicer/workflow/output/307
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/307; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/307
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan308; Source output folder: /prisma-data1/bicer/workflow/output/308
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/308; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/308
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan309; Source output folder: /prisma-data1/bicer/workflow/output/309
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/309; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/309
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan310; Source output folder: /prisma-data1/bicer/workflow/output/310
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/310; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/310
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan311; Source output folder: /prisma-data1/bicer/workflow/output/311
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/311; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/311
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan312; Source output folder: /prisma-data1/bicer/workflow/output/312
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/312; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/312
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan313; Source output folder: /prisma-data1/bicer/workflow/output/313
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/313; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/313
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan314; Source output folder: /prisma-data1/bicer/workflow/output/314
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/314; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/314
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan315; Source output folder: /prisma-data1/bicer/workflow/output/315
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/315; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/315
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan316; Source output folder: /prisma-data1/bicer/workflow/output/316
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/316; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/316
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan317; Source output folder: /prisma-data1/bicer/workflow/output/317
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/317; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/317
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan318; Source output folder: /prisma-data1/bicer/workflow/output/318
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/318; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/318
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan319; Source output folder: /prisma-data1/bicer/workflow/output/319
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/319; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/319
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan320; Source output folder: /prisma-data1/bicer/workflow/output/320
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/320; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/320
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan321; Source output folder: /prisma-data1/bicer/workflow/output/321
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/321; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/321
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan322; Source output folder: /prisma-data1/bicer/workflow/output/322
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/322; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/322
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan323; Source output folder: /prisma-data1/bicer/workflow/output/323
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/323; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/323
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan324; Source output folder: /prisma-data1/bicer/workflow/output/324
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/324; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/324
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan325; Source output folder: /prisma-data1/bicer/workflow/output/325
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/325; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/325
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan326; Source output folder: /prisma-data1/bicer/workflow/output/326
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/326; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/326
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan327; Source output folder: /prisma-data1/bicer/workflow/output/327
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/327; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/327
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan328; Source output folder: /prisma-data1/bicer/workflow/output/328
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/328; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/328
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan329; Source output folder: /prisma-data1/bicer/workflow/output/329
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/329; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/329
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan330; Source output folder: /prisma-data1/bicer/workflow/output/330
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/330; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/330
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan331; Source output folder: /prisma-data1/bicer/workflow/output/331
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/331; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/331
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan332; Source output folder: /prisma-data1/bicer/workflow/output/332
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/332; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/332
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan333; Source output folder: /prisma-data1/bicer/workflow/output/333
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/333; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/333
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan334; Source output folder: /prisma-data1/bicer/workflow/output/334
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/334; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/334
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan335; Source output folder: /prisma-data1/bicer/workflow/output/335
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/335; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/335
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan336; Source output folder: /prisma-data1/bicer/workflow/output/336
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/336; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/336
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan337; Source output folder: /prisma-data1/bicer/workflow/output/337
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/337; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/337
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan338; Source output folder: /prisma-data1/bicer/workflow/output/338
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/338; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/338
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan339; Source output folder: /prisma-data1/bicer/workflow/output/339
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/339; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/339
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan340; Source output folder: /prisma-data1/bicer/workflow/output/340
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/340; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/340
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan341; Source output folder: /prisma-data1/bicer/workflow/output/341
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/341; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/341
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan342; Source output folder: /prisma-data1/bicer/workflow/output/342
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/342; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/342
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan343; Source output folder: /prisma-data1/bicer/workflow/output/343
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/343; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/343
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan344; Source output folder: /prisma-data1/bicer/workflow/output/344
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/344; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/344
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan345; Source output folder: /prisma-data1/bicer/workflow/output/345
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/345; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/345
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan346; Source output folder: /prisma-data1/bicer/workflow/output/346
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/346; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/346
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan347; Source output folder: /prisma-data1/bicer/workflow/output/347
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/347; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/347
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan348; Source output folder: /prisma-data1/bicer/workflow/output/348
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/348; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/348
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan349; Source output folder: /prisma-data1/bicer/workflow/output/349
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/349; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/349
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan350; Source output folder: /prisma-data1/bicer/workflow/output/350
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/350; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/350
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan351; Source output folder: /prisma-data1/bicer/workflow/output/351
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/351; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/351
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan352; Source output folder: /prisma-data1/bicer/workflow/output/352
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/352; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/352
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan353; Source output folder: /prisma-data1/bicer/workflow/output/353
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/353; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/353
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan354; Source output folder: /prisma-data1/bicer/workflow/output/354
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/354; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/354
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan355; Source output folder: /prisma-data1/bicer/workflow/output/355
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/355; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/355
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan356; Source output folder: /prisma-data1/bicer/workflow/output/356
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/356; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/356
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan357; Source output folder: /prisma-data1/bicer/workflow/output/357
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/357; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/357
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan358; Source output folder: /prisma-data1/bicer/workflow/output/358
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/358; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/358
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan359; Source output folder: /prisma-data1/bicer/workflow/output/359
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/359; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/359
#
# Source input folder: /prisma-data1/bicer/workflow/input/scan360; Source output folder: /prisma-data1/bicer/workflow/output/360
# Dest. input folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/360; Dest. output folder: /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/360

# %%
theta_fx_endpoint = 'f765db7a-038c-47ea-9176-d81de31c054f' #'7f42390d-849a-42a7-905c-db6b22af28f7' # #FuncX endpoint

#src_endpoint = '9c9cb97e-de86-11e6-9d15-22000a1e3b52' #'aps#data' # Voyager
src_endpoint = 'dd916908-0072-11e7-badc-22000b9a448b' #'hostel' #aps/workstation
dest_endpoint = '08925f04-569f-11e7-bef8-22000b9a448b' #'alcf#dtn_theta' # Theta DTN # 'e09e65f5-6d04-11e5-ba46-22000b92c6ec' #

# Ptycho recon params
script_path = '/home/bicer/projects/tike/scripts/mpi_tike-recon.py'
python_path = "/home/bicer/miniconda3/envs/ptycho/bin/python"

rec_alg = 'cgrad'
rec_nmodes = 8
rec_upd_pos = False
rec_niter = 10
rec_output_freq = 5
rec_recover_psi = True
rec_recover_probe= True
rec_recover_positions = False
rec_model = 'gaussian'
rec_ngpu = 1
rec_use_mpi = False

flow_inputs = []

for (src_input_folder_path, src_output_folder_path, 
     dest_input_folder_path, dest_output_folder_path ) in zip(
    src_input_folder_paths, src_output_folder_paths, 
    dest_input_folder_paths, dest_output_folder_paths):
    
    flow_input = {
        "input": {
            "source_endpoint": f"{src_endpoint}",
            "source_path": f"{src_input_folder_path}",
            "dest_endpoint": dest_endpoint,
            "dest_path": f"{dest_input_folder_path}",

            "result_path": f"{dest_output_folder_path}",#f"{dest_resultpath}/out_{src_filename}",
            "source_result_path": f"{src_output_folder_path}", #/out_{src_filename}",
            "fx_ep": f"{theta_fx_endpoint}",
            "fx_id": f"{func_cp_uuid}", #f"{func_hl_uuid}" #
            #"fx_id": f"{func_ptycho_uuid}",
            #"params": {'ifpath': f"{dest_input_folder_path}",
            #           'ofpath': f"{dest_output_folder_path}/",
            #           'script_path': script_path,
            #           'python_path': python_path,
            #           'rec_alg': rec_alg,
            #           'rec_nmodes': rec_nmodes,
            #           'rec_upd_pos': rec_upd_pos,
            #           'rec_niter': rec_niter,
            #           'rec_output_freq': rec_output_freq,
            #           'rec_recover_psi': rec_recover_psi,
            #           'rec_recover_probe': rec_recover_probe,
            #           'rec_recover_positions': rec_recover_positions,
            #           'rec_model': rec_model,
            #           'rec_ngpu': rec_ngpu,
            #           'rec_use_mpi': rec_use_mpi}
            "params": {"ifpath": f"{dest_input_folder_path}",
                       "ofpath": f"{dest_output_folder_path}"}
        }
    }
    flow_inputs.append(flow_input)

#print(f"transfer file from {src_endpoint}#{src_filepath}/{src_filename} to {dest_endpoint}#{dest_filepath}/")
#print(f"recon file:{dest_filepath}/{src_filename} output:{dest_resultpath}/")
#print(f"transfer file from {dest_endpoint}:{dest_resultpath} to {src_endpoint}#{src_result_path}/")

# %%
print(len(flow_inputs))
# Out:
# 168

# %%
flows_client = create_flows_client(CLIENT_ID)
flow = flows_client.deploy_flow(flow_definition, title="Simple ptycho data analysis flow")
flow_id = flow['id']
flow_scope = flow['globus_auth_scope']

print(flow)
#print(f'Newly created flow with id:\n{flow_id}\nand scope:\n{flow_scope}')
# Out:
# GlobusHTTPResponse({'action_url': 'https://flows.globus.org/flows/e66c2ee5-8e7f-4296-997b-b791131052df', 'administered_by': [], 'api_version': '1.0', 'created_by': 'urn:globus:auth:identity:a478e9c0-d274-11e5-9901-63aaec352b80', 'definition': {'Comment': 'An analysis flow', 'StartAt': 'Transfer', 'States': {'Analyze': {'ActionScope': 'https://auth.globus.org/scopes/facd7ccc-c5f4-42aa-916b-a0e270e2c2a9/automate2', 'ActionUrl': 'https://api.funcx.org/automate', 'Comment': 'Run a funcX function', 'Next': 'Transfer2', 'Parameters': {'tasks': [{'endpoint.$': '$.input.fx_ep', 'func.$': '$.input.fx_id', 'payload.$': '$.input.params'}]}, 'ResultPath': '$.AnalyzeResult', 'Type': 'Action', 'WaitTime': 3600}, 'Transfer': {'ActionScope': 'https://auth.globus.org/scopes/actions.globus.org/transfer/transfer', 'ActionUrl': 'https://actions.automate.globus.org/transfer/transfer', 'Comment': 'Initial transfer', 'Next': 'Analyze', 'Parameters': {'destination_endpoint_id.$': '$.input.dest_endpoint', 'source_endpoint_id.$': '$.input.source_endpoint', 'transfer_items': [{'destination_path.$': '$.input.dest_path', 'recursive': True, 'source_path.$': '$.input.source_path'}]}, 'ResultPath': '$.Transfer1Result', 'Type': 'Action', 'WaitTime': 1800}, 'Transfer2': {'ActionScope': 'https://auth.globus.org/scopes/actions.globus.org/transfer/transfer', 'ActionUrl': 'https://actions.automate.globus.org/transfer/transfer', 'Comment': 'Return transfer', 'End': True, 'Parameters': {'destination_endpoint_id.$': '$.input.source_endpoint', 'source_endpoint_id.$': '$.input.dest_endpoint', 'transfer_items': [{'destination_path.$': '$.input.source_result_path', 'recursive': True, 'source_path.$': '$.input.result_path'}]}, 'ResultPath': '$.Transfer2Result', 'Type': 'Action', 'WaitTime': 1800}}}, 'description': '', 'globus_auth_scope': 'https://auth.globus.org/scopes/e66c2ee5-8e7f-4296-997b-b791131052df/flow_e66c2ee5_8e7f_4296_997b_b791131052df_user', 'globus_auth_username': 'e66c2ee5-8e7f-4296-997b-b791131052df@clients.auth.globus.org', 'id': 'e66c2ee5-8e7f-4296-997b-b791131052df', 'keywords': [], 'log_supported': True, 'principal_urn': 'urn:globus:auth:identity:e66c2ee5-8e7f-4296-997b-b791131052df', 'runnable_by': [], 'subtitle': '', 'synchronous': False, 'title': 'Simple ptycho data analysis flow', 'types': ['Action'], 'visible_to': []})

# %%
MAX_QSIZE =128
q0 = deque()
q1 = deque()

for i in range(len(flow_inputs)):
    if i<MAX_QSIZE:
        flow_action = flows_client.run_flow(flow_id, flow_scope, flow_inputs[i])
        q1.append(flow_action)
        print(f"Flow {i} initiated and added to q1: {flow_action['action_id']}")
    else: 
        q0.append(flow_inputs[i])
        print(f"Flow input {i} added to q0")

i=-1
while len(q1)>0:
    #time.sleep(0.5)
    i = (i+1)%len(q1)
    flow = flows_client.flow_action_status(flow_id, flow_scope, q1[i]['action_id'])
    print(f"len(q0)={len(q0)}; len(q1)={len(q1)}; i={i}")
    print(f"Flow {i} status: {q1[i]['action_id']}: {flow['status']}")
    if flow['status'] == 'SUCCEEDED':
        del q1[i]
        if len(q0)>0:
            flow_input = q0.popleft()
            flow_action = flows_client.run_flow(flow_id, flow_scope, flow_input)
            q1.append(flow_action)
            print(f"New flow initiated and added to the q1: {flow_action['action_id']}")
            print(f"Copy from {flow_input['input']['params']['ifpath']} to {flow_input['input']['params']['ofpath']}")
# Out:
# Starting login with Globus Auth, press ^C to cancel.
# Flow 0 initiated and added to q1: c7d93139-f573-448a-b752-085c690f1918
# Flow 1 initiated and added to q1: 81fe19f0-08f2-422a-91d5-aaa86462cf99
# Flow 2 initiated and added to q1: e4e2db74-ba5f-4905-b5f6-b0026411fe5d
# Flow 3 initiated and added to q1: 89e0a874-fd56-41d5-b5c3-5ef76c6b70b7
# Flow 4 initiated and added to q1: 58a61961-251a-4d38-878a-6b2254e2abdf
# Flow 5 initiated and added to q1: 06493b02-2ced-4640-93e6-b478b145276f
# Flow 6 initiated and added to q1: 1c067620-9c05-4edb-a12c-1e35c33b9f94
# Flow 7 initiated and added to q1: 29170eed-3b35-4bd3-90e3-789732b0e9da
# Flow 8 initiated and added to q1: 257b3057-3c9f-46c2-932a-074cc68fc7bc
# Flow 9 initiated and added to q1: e0dc02ec-242c-4890-8550-83b141eb4c49
# Flow 10 initiated and added to q1: 8ad6ba1a-756f-4d40-8537-203fcf4fda6d
# Flow 11 initiated and added to q1: 4ed2333b-8aa1-4dfe-9303-6f2b3201f65a
# Flow 12 initiated and added to q1: daba3748-2672-4091-9d9d-7f12023a0bca
# Flow 13 initiated and added to q1: 17266567-c5c0-43e3-b8fb-309578242b6f
# Flow 14 initiated and added to q1: 55c80cb8-5ca7-411e-b4d2-a068dda2d4fe
# Flow 15 initiated and added to q1: 3982e79a-b23b-4552-b0fa-07c9f3eceb19
# Flow 16 initiated and added to q1: 6c827a84-f3ca-4174-8280-d120afe0bd5a
# Flow 17 initiated and added to q1: e9c42de4-9d0d-48ee-abe9-d41e9a8d811d
# Flow 18 initiated and added to q1: fa91a6ab-4818-4cd3-837d-e7b226cef50e
# Flow 19 initiated and added to q1: 48afd98b-2108-4b30-8095-0637590f7546
# Flow 20 initiated and added to q1: 13321339-ba98-4390-9d27-495f46949f5b
# Flow 21 initiated and added to q1: c9148677-9d26-431a-8b74-f4f847eb034a
# Flow 22 initiated and added to q1: a0c0d958-f400-41f4-8d81-d2ff875ba970
# Flow 23 initiated and added to q1: 14b08e89-f0eb-42c1-9a52-c22fa81c0158
# Flow 24 initiated and added to q1: 43b88032-11fe-4aca-8930-cd1b5cffe486
# Flow 25 initiated and added to q1: 2811cf79-842e-4a8e-b69c-53809f812377
# Flow 26 initiated and added to q1: 89c4b1a6-add7-4076-a3b0-f08f8ae6f0be
# Flow 27 initiated and added to q1: c682c7b9-a3ff-423b-8256-cd329b026f49
# Flow 28 initiated and added to q1: 19fae7ae-1c6a-4c1f-8722-e9f6411753e4
# Flow 29 initiated and added to q1: ee43b122-75b7-4fa3-a4af-805b3230bf5e
# Flow 30 initiated and added to q1: 39f9e376-8969-4cc5-88e4-3e1c8359c791
# Flow 31 initiated and added to q1: 634771fd-9f43-4c1f-b756-c9ae3dd5ebf9
# Flow 32 initiated and added to q1: e6bcf430-1a9d-46df-a758-6bcd4021395f
# Flow 33 initiated and added to q1: b786a84f-d2db-472f-91f4-7e2499d9fe30
# Flow 34 initiated and added to q1: 7b1cfe06-28cb-45ad-9e8c-f7b817fb4052
# Flow 35 initiated and added to q1: 910abc27-b1f2-4d3d-ae68-beabb6fb581d
# Flow 36 initiated and added to q1: b76e9dce-989c-478c-a79f-152ce37149ff
# Flow 37 initiated and added to q1: 8c45f9dc-ee92-49d8-b181-b05bb20c1712
# Flow 38 initiated and added to q1: 7dc42a10-4c4b-4998-8e8c-62c75e505403
# Flow 39 initiated and added to q1: 245fa4ae-5e14-41f4-8dc2-d18bbbb44bfa
# Flow 40 initiated and added to q1: 81b88613-11e5-47d2-90fd-a2b152ec0c2e
# Flow 41 initiated and added to q1: 0f5362ce-2d28-4ae2-a3f6-43bed5584efa
# Flow 42 initiated and added to q1: bf28d20a-0591-4a08-b00a-b827d84b2491
# Flow 43 initiated and added to q1: d39ce360-d9b3-4a55-9c1a-5ade3803bad5
# Flow 44 initiated and added to q1: 9b1bdfb5-4b34-49f2-a443-199fa9f523e9
# Flow 45 initiated and added to q1: b4f2945b-7fca-4a5b-b4ab-350ceaae515f
# Flow 46 initiated and added to q1: db80c389-2b04-49bb-a6f4-12aec322aa66
# Flow 47 initiated and added to q1: 9269e6af-ec3c-4c3d-a927-513bf3f63aa2
# Flow 48 initiated and added to q1: 9400799b-97e8-4966-9681-d8cd86aa883b
# Flow 49 initiated and added to q1: 33ba5b6e-27bb-4082-8e59-e0c96ae426d6
# Flow 50 initiated and added to q1: e38d69d6-1fd5-4553-8a7d-98115d5c7b54
# Flow 51 initiated and added to q1: 56fb77bf-aa44-4b38-ba9a-b17c0926eee8
# Flow 52 initiated and added to q1: 497d566f-24d2-44b8-9a97-2e7ccc230f79
# Flow 53 initiated and added to q1: 75c5e35f-838b-4919-b32b-0d564b72828a
# Flow 54 initiated and added to q1: f4b24157-0d95-4de1-a808-fef36f11dd75
# Flow 55 initiated and added to q1: 2ffd893b-fdd1-44aa-b993-9a13452a311a
# Flow 56 initiated and added to q1: 44670b95-b232-4e4a-84b4-9d380ab722a8
# Flow 57 initiated and added to q1: 1efe6dea-ca34-419b-bd48-7dcc805ade4a
# Flow 58 initiated and added to q1: d2ff67e2-6fa1-4939-985c-1b879554226e
# Flow 59 initiated and added to q1: 7c4d0a79-fb54-411f-809d-a87c175bfadb
# Flow 60 initiated and added to q1: a7d9d209-4461-4452-8b5a-3fee7dd1286d
# Flow 61 initiated and added to q1: e4980640-a04b-4222-aae9-74fff34518e5
# Flow 62 initiated and added to q1: cbfe2e6b-4867-4ecb-b0f7-703e86034487
# Flow 63 initiated and added to q1: eaf65409-bab4-4e9b-844e-ab9b8f643f82
# Flow 64 initiated and added to q1: 984ec2bc-7d8c-40ff-99db-293796377659
# Flow 65 initiated and added to q1: f80eaf67-60d4-4ed7-a64d-a08ce06ed01e
# Flow 66 initiated and added to q1: a237e1b7-cfc7-4232-acb3-df9674b9691b
# Flow 67 initiated and added to q1: 0939a9f7-35f8-42ab-835f-147e146b66f5
# Flow 68 initiated and added to q1: a653b8ea-6895-4bf6-94ca-302cdb2e10d8
# Flow 69 initiated and added to q1: 7323937e-a37c-4731-9700-126d284a6b2d
# Flow 70 initiated and added to q1: 732e31a3-aa64-42dd-ad59-469f61d33427
# Flow 71 initiated and added to q1: 30761653-28af-4270-8dad-94027a81e760
# Flow 72 initiated and added to q1: c101afbb-8f9a-47e6-9d82-e44cc20e7b9c
# Flow 73 initiated and added to q1: 22cf92f3-30ce-4eba-97ad-def9a2e29a1d
# Flow 74 initiated and added to q1: 57638373-ed93-4b8d-b7bd-8c282c7d6524
# Flow 75 initiated and added to q1: dc351606-8427-42ab-b9c8-cf5250ff28fe
# Flow 76 initiated and added to q1: 107cf103-dc14-49d6-b024-8f94b6afa711
# Flow 77 initiated and added to q1: e8bb5f3b-46e6-454d-a80f-6a8f8edd00b5
# Flow 78 initiated and added to q1: 89491c9d-3292-4ab0-a8ef-c3e67adfa3c2
# Flow 79 initiated and added to q1: 4babba79-267e-40eb-9681-7142f8cd639b
# Flow 80 initiated and added to q1: 6da84850-a4a0-4faf-b763-53552ccd3055
# Flow 81 initiated and added to q1: 616840bc-a55f-412a-96f7-c66050f18099
# Flow 82 initiated and added to q1: fc2efe17-98ef-4e75-8fe9-16a4da2c5151
# Flow 83 initiated and added to q1: d920b9ad-97c4-4dc8-9bb7-40cf32145257
# Flow 84 initiated and added to q1: aea8759e-a125-4a9e-80a5-74731db602dc
# Flow 85 initiated and added to q1: aad174dd-bad3-48e8-aeb7-7be20fe9b98f
# Flow 86 initiated and added to q1: af95e97f-e74d-42b6-8dc1-8d4714687354
# Flow 87 initiated and added to q1: 40101592-4ab3-47cf-9bf5-12a35b5567cd
# Flow 88 initiated and added to q1: 0d99b1ac-23ee-47ff-9bce-584357b08347
# Flow 89 initiated and added to q1: 1a1375c5-fc97-47fe-b2b7-7f196b050113
# Flow 90 initiated and added to q1: fc12a65b-5a62-46e6-97df-9c22822bd98e
# Flow 91 initiated and added to q1: 223c1ba5-2e88-4c9e-8b5e-0fb38dc6bb28
# Flow 92 initiated and added to q1: 8241a1a9-bb53-4a66-b85d-c44b499a28e9
# Flow 93 initiated and added to q1: 50eb8da0-60ce-4369-8c1e-0859f309bee8
# Flow 94 initiated and added to q1: d6a92a80-d68c-4aa5-8a9b-21260b6baefd
# Flow 95 initiated and added to q1: da7a0183-315a-4978-ae66-faf42d114a75
# Flow 96 initiated and added to q1: 8c8324d2-3cde-4820-9a35-ddad7f916de2
# Flow 97 initiated and added to q1: c7a5d637-fb6f-4faf-9ebc-1ff3780df49a
# Flow 98 initiated and added to q1: 2c990840-901f-46a7-a9b9-d3154467b3b7
# Flow 99 initiated and added to q1: a9b2f1bd-3bf1-4965-8462-8c66c5958b26
# Flow 100 initiated and added to q1: 42fb3dde-143d-48ce-a989-b131b098d686
# Flow 101 initiated and added to q1: 32e91790-a522-4bba-a5b7-7b5171b191cc
# Flow 102 initiated and added to q1: 3c2f5026-0881-4a2d-a8bc-2b7678e4c9dc
# Flow 103 initiated and added to q1: 9f5db273-41a7-4a64-8701-a857c57ae05e
# Flow 104 initiated and added to q1: 1399d5b7-1c11-42ab-9a65-041c6710c2da
# Flow 105 initiated and added to q1: eea547c5-70e6-4b59-be5c-b9f813f2ae75
# Flow 106 initiated and added to q1: e2b7c67a-c087-4281-98d7-ddaaaf2836e6
# Flow 107 initiated and added to q1: e05f3279-b7a5-4547-a435-ad1a5c2f5d45
# Flow 108 initiated and added to q1: 86bade1b-9b22-45fe-ac1d-d7d169bf9434
# Flow 109 initiated and added to q1: 0f4bbb2d-5707-44d2-9f44-335e9502f50f
# Flow 110 initiated and added to q1: 703bed2b-e3aa-4e38-9031-0ffa2dbbacec
# Flow 111 initiated and added to q1: a2ff714a-fce7-48e6-af49-d210ac6df1d6
# Flow 112 initiated and added to q1: 74abea36-253f-4a45-9314-5f5d25001da5
# Flow 113 initiated and added to q1: e5c38ea3-b3bf-480c-a23e-8f242e563529
# Flow 114 initiated and added to q1: 8b3eb625-a741-48a7-a104-bfdffb292b4f
# Flow 115 initiated and added to q1: a78dcaf7-49c0-4f20-8c65-71caf0c785ae
# Flow 116 initiated and added to q1: 5bfb28c4-9ebb-46f6-921d-ecc70bedb9a0
# Flow 117 initiated and added to q1: 118ff4a9-aee1-4d19-9b80-35b77d65809c
# Flow 118 initiated and added to q1: 9c59713e-b100-400a-ab6e-58a47296dd12
# Flow 119 initiated and added to q1: d9d33256-f3da-486f-b4fc-570337b250ad
# Flow 120 initiated and added to q1: 91e31d7b-576d-4663-b42b-3d2c25695196
# Flow 121 initiated and added to q1: e2bf85d5-e4f9-41b3-8069-b2af7b29c845
# Flow 122 initiated and added to q1: 7d231456-7cdb-4173-8d0d-e196a689a762
# Flow 123 initiated and added to q1: c5ac6131-2124-45cd-9e3d-a71310ce88a3
# Flow 124 initiated and added to q1: 2b19c83c-a8e2-4c32-a568-37c8446646ea
# Flow 125 initiated and added to q1: 333892dd-d4df-4f51-918f-8a13f6e3d3ae
# Flow 126 initiated and added to q1: 32b4c3db-fef6-4b55-a660-fecd55f12747
# Flow 127 initiated and added to q1: 4df2b814-340a-46f4-b725-c378a289650c
# Flow input 128 added to q0
# Flow input 129 added to q0
# Flow input 130 added to q0
# Flow input 131 added to q0
# Flow input 132 added to q0
# Flow input 133 added to q0
# Flow input 134 added to q0
# Flow input 135 added to q0
# Flow input 136 added to q0
# Flow input 137 added to q0
# Flow input 138 added to q0
# Flow input 139 added to q0
# Flow input 140 added to q0
# Flow input 141 added to q0
# Flow input 142 added to q0
# Flow input 143 added to q0
# Flow input 144 added to q0
# Flow input 145 added to q0
# Flow input 146 added to q0
# Flow input 147 added to q0
# Flow input 148 added to q0
# Flow input 149 added to q0
# Flow input 150 added to q0
# Flow input 151 added to q0
# Flow input 152 added to q0
# Flow input 153 added to q0
# Flow input 154 added to q0
# Flow input 155 added to q0
# Flow input 156 added to q0
# Flow input 157 added to q0
# Flow input 158 added to q0
# Flow input 159 added to q0
# Flow input 160 added to q0
# Flow input 161 added to q0
# Flow input 162 added to q0
# Flow input 163 added to q0
# Flow input 164 added to q0
# Flow input 165 added to q0
# Flow input 166 added to q0
# Flow input 167 added to q0
# len(q0)=40; len(q1)=128; i=0
# Flow 0 status: c7d93139-f573-448a-b752-085c690f1918: SUCCEEDED
# New flow initiated and added to the q1: 6bdb6e0b-a661-489a-acc0-78e1b8b90ede
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/321 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/321
# len(q0)=39; len(q1)=128; i=1
# Flow 1 status: e4e2db74-ba5f-4905-b5f6-b0026411fe5d: SUCCEEDED
# New flow initiated and added to the q1: 4ca47b57-819a-44f5-832b-fc9e543c0d41
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/322 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/322
# len(q0)=38; len(q1)=128; i=2
# Flow 2 status: 58a61961-251a-4d38-878a-6b2254e2abdf: SUCCEEDED
# New flow initiated and added to the q1: c6cff194-d37b-4b4e-8bf9-5bd38c8fa46e
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/323 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/323
# len(q0)=37; len(q1)=128; i=3
# Flow 3 status: 1c067620-9c05-4edb-a12c-1e35c33b9f94: SUCCEEDED
# New flow initiated and added to the q1: 367925b7-ae65-4959-983f-6b6c13a5dec8
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/324 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/324
# len(q0)=36; len(q1)=128; i=4
# Flow 4 status: 257b3057-3c9f-46c2-932a-074cc68fc7bc: SUCCEEDED
# New flow initiated and added to the q1: 0c808394-11dd-4c00-b70b-df877eecdfc4
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/325 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/325
# len(q0)=35; len(q1)=128; i=5
# Flow 5 status: 8ad6ba1a-756f-4d40-8537-203fcf4fda6d: SUCCEEDED
# New flow initiated and added to the q1: a585da8d-0509-45e8-8b0f-2a7d35791bbe
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/326 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/326
# len(q0)=34; len(q1)=128; i=6
# Flow 6 status: daba3748-2672-4091-9d9d-7f12023a0bca: SUCCEEDED
# New flow initiated and added to the q1: 3be91208-7eb0-47bd-85ee-f55496fc4e8f
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/327 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/327
# len(q0)=33; len(q1)=128; i=7
# Flow 7 status: 55c80cb8-5ca7-411e-b4d2-a068dda2d4fe: SUCCEEDED
# New flow initiated and added to the q1: 5b67f163-3ad1-4e88-b75c-3e1cc5b3aeea
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/328 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/328
# len(q0)=32; len(q1)=128; i=8
# Flow 8 status: 6c827a84-f3ca-4174-8280-d120afe0bd5a: SUCCEEDED
# New flow initiated and added to the q1: 2df2fb94-0b9c-4fd5-b80f-8c8ec5a0d975
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/329 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/329
# len(q0)=31; len(q1)=128; i=9
# Flow 9 status: fa91a6ab-4818-4cd3-837d-e7b226cef50e: SUCCEEDED
# New flow initiated and added to the q1: cda2f556-05d1-4adf-95d8-070f82096253
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/330 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/330
# len(q0)=30; len(q1)=128; i=10
# Flow 10 status: 13321339-ba98-4390-9d27-495f46949f5b: SUCCEEDED
# New flow initiated and added to the q1: 1ea99140-e75d-49ce-a4d3-c0b20ecc21f4
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/331 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/331
# len(q0)=29; len(q1)=128; i=11
# Flow 11 status: a0c0d958-f400-41f4-8d81-d2ff875ba970: SUCCEEDED
# New flow initiated and added to the q1: 03574fd1-6c20-42ec-a24c-eed1314742f3
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/332 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/332
# len(q0)=28; len(q1)=128; i=12
# Flow 12 status: 43b88032-11fe-4aca-8930-cd1b5cffe486: SUCCEEDED
# New flow initiated and added to the q1: 9e76efaa-c992-41c2-a718-19ada52efa9d
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/333 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/333
# len(q0)=27; len(q1)=128; i=13
# Flow 13 status: 89c4b1a6-add7-4076-a3b0-f08f8ae6f0be: SUCCEEDED
# New flow initiated and added to the q1: f1a97d0b-959a-4aee-bd42-d69d76e625e5
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/334 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/334
# len(q0)=26; len(q1)=128; i=14
# Flow 14 status: 19fae7ae-1c6a-4c1f-8722-e9f6411753e4: SUCCEEDED
# New flow initiated and added to the q1: ed473e19-1991-43e4-a8e0-d80527d493a0
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/335 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/335
# len(q0)=25; len(q1)=128; i=15
# Flow 15 status: 39f9e376-8969-4cc5-88e4-3e1c8359c791: SUCCEEDED
# New flow initiated and added to the q1: 70dc0380-9e37-4427-8e1b-6ec8333443fa
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/336 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/336
# len(q0)=24; len(q1)=128; i=16
# Flow 16 status: e6bcf430-1a9d-46df-a758-6bcd4021395f: SUCCEEDED
# New flow initiated and added to the q1: 0961209c-48d9-4fd4-a988-e7cdb3bd84b6
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/337 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/337
# len(q0)=23; len(q1)=128; i=17
# Flow 17 status: 7b1cfe06-28cb-45ad-9e8c-f7b817fb4052: SUCCEEDED
# New flow initiated and added to the q1: e6045272-95d0-4149-b6a8-53db46cbccaf
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/338 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/338
# len(q0)=22; len(q1)=128; i=18
# Flow 18 status: b76e9dce-989c-478c-a79f-152ce37149ff: SUCCEEDED
# New flow initiated and added to the q1: ff74c8dd-2bbf-4a74-9b5e-6bb5915532e3
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/339 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/339
# len(q0)=21; len(q1)=128; i=19
# Flow 19 status: 7dc42a10-4c4b-4998-8e8c-62c75e505403: SUCCEEDED
# New flow initiated and added to the q1: 3142d816-8cf7-450e-a362-006a5b72d84f
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/340 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/340
# len(q0)=20; len(q1)=128; i=20
# Flow 20 status: 81b88613-11e5-47d2-90fd-a2b152ec0c2e: SUCCEEDED
# New flow initiated and added to the q1: ec54c917-cfe8-422e-81b1-1eabb4f9d562
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/341 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/341
# len(q0)=19; len(q1)=128; i=21
# Flow 21 status: bf28d20a-0591-4a08-b00a-b827d84b2491: SUCCEEDED
# New flow initiated and added to the q1: 2af04b18-0c27-4fef-a451-70a4194cf7bc
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/342 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/342
# len(q0)=18; len(q1)=128; i=22
# Flow 22 status: 9b1bdfb5-4b34-49f2-a443-199fa9f523e9: SUCCEEDED
# New flow initiated and added to the q1: d043b8d7-0c58-43e3-9310-b26529dbdc14
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/343 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/343
# len(q0)=17; len(q1)=128; i=23
# Flow 23 status: db80c389-2b04-49bb-a6f4-12aec322aa66: SUCCEEDED
# New flow initiated and added to the q1: 053aa79e-c4c0-4b95-a97d-844128cd007f
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/344 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/344
# len(q0)=16; len(q1)=128; i=24
# Flow 24 status: 9400799b-97e8-4966-9681-d8cd86aa883b: SUCCEEDED
# New flow initiated and added to the q1: f87ec444-f848-4f4b-9d3e-7508f2c03118
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/345 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/345
# len(q0)=15; len(q1)=128; i=25
# Flow 25 status: e38d69d6-1fd5-4553-8a7d-98115d5c7b54: SUCCEEDED
# New flow initiated and added to the q1: e1d96c7e-bb68-4508-85b4-fccede42b96b
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/346 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/346
# len(q0)=14; len(q1)=128; i=26
# Flow 26 status: 497d566f-24d2-44b8-9a97-2e7ccc230f79: SUCCEEDED
# New flow initiated and added to the q1: 6fd64fc7-887d-41f1-9e38-2f8f5bd62501
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/347 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/347
# len(q0)=13; len(q1)=128; i=27
# Flow 27 status: f4b24157-0d95-4de1-a808-fef36f11dd75: SUCCEEDED
# New flow initiated and added to the q1: 195200a9-0bfc-461b-a460-b68f4d982fae
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/348 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/348
# len(q0)=12; len(q1)=128; i=28
# Flow 28 status: 44670b95-b232-4e4a-84b4-9d380ab722a8: SUCCEEDED
# New flow initiated and added to the q1: 009fd2d6-14ce-4bb2-af23-50fd8213ec69
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/349 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/349
# len(q0)=11; len(q1)=128; i=29
# Flow 29 status: d2ff67e2-6fa1-4939-985c-1b879554226e: SUCCEEDED
# New flow initiated and added to the q1: 8a800643-a802-47b8-b1d3-183b5b30cc97
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/350 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/350
# len(q0)=10; len(q1)=128; i=30
# Flow 30 status: a7d9d209-4461-4452-8b5a-3fee7dd1286d: SUCCEEDED
# New flow initiated and added to the q1: d51b11b1-9345-4a61-b159-779449499bf0
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/351 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/351
# len(q0)=9; len(q1)=128; i=31
# Flow 31 status: cbfe2e6b-4867-4ecb-b0f7-703e86034487: SUCCEEDED
# New flow initiated and added to the q1: 2014c77a-f572-4b93-ae44-11e00b21632c
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/352 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/352
# len(q0)=8; len(q1)=128; i=32
# Flow 32 status: 984ec2bc-7d8c-40ff-99db-293796377659: SUCCEEDED
# New flow initiated and added to the q1: ef8ae8ba-5c92-4482-8098-84a623e2c5c3
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/353 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/353
# len(q0)=7; len(q1)=128; i=33
# Flow 33 status: a237e1b7-cfc7-4232-acb3-df9674b9691b: SUCCEEDED
# New flow initiated and added to the q1: 931baa9f-945a-44c9-b877-21a666c85f79
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/354 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/354
# len(q0)=6; len(q1)=128; i=34
# Flow 34 status: a653b8ea-6895-4bf6-94ca-302cdb2e10d8: SUCCEEDED
# New flow initiated and added to the q1: 880154c7-8655-4346-a8cb-c3444e5c6688
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/355 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/355
# len(q0)=5; len(q1)=128; i=35
# Flow 35 status: 732e31a3-aa64-42dd-ad59-469f61d33427: SUCCEEDED
# New flow initiated and added to the q1: 6aecb044-8bc3-4caa-baae-8c2087280deb
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/356 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/356
# len(q0)=4; len(q1)=128; i=36
# Flow 36 status: c101afbb-8f9a-47e6-9d82-e44cc20e7b9c: SUCCEEDED
# New flow initiated and added to the q1: e01a3902-d3dc-4724-959a-6d97230d00a2
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/357 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/357
# len(q0)=3; len(q1)=128; i=37
# Flow 37 status: 57638373-ed93-4b8d-b7bd-8c282c7d6524: SUCCEEDED
# New flow initiated and added to the q1: 5e822d28-ab80-4a06-99dc-725c1da2d6e7
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/358 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/358
# len(q0)=2; len(q1)=128; i=38
# Flow 38 status: 107cf103-dc14-49d6-b024-8f94b6afa711: SUCCEEDED
# New flow initiated and added to the q1: cdc35997-8999-420e-8a3a-aabc5fd3b1d1
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/359 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/359
# len(q0)=1; len(q1)=128; i=39
# Flow 39 status: 89491c9d-3292-4ab0-a8ef-c3e67adfa3c2: SUCCEEDED
# New flow initiated and added to the q1: 4ee280d2-e35e-4b5a-bb20-648dea3d028a
# Copy from /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/input/360 to /grand/hp-ptycho/bicer/ptycho/comm_33IDD/globus_automate/output/360
# len(q0)=0; len(q1)=128; i=40
# Flow 40 status: 6da84850-a4a0-4faf-b763-53552ccd3055: SUCCEEDED
# len(q0)=0; len(q1)=127; i=41
# Flow 41 status: fc2efe17-98ef-4e75-8fe9-16a4da2c5151: SUCCEEDED
# len(q0)=0; len(q1)=126; i=42
# Flow 42 status: aea8759e-a125-4a9e-80a5-74731db602dc: SUCCEEDED
# len(q0)=0; len(q1)=125; i=43
# Flow 43 status: af95e97f-e74d-42b6-8dc1-8d4714687354: SUCCEEDED
# len(q0)=0; len(q1)=124; i=44
# Flow 44 status: 0d99b1ac-23ee-47ff-9bce-584357b08347: SUCCEEDED
# len(q0)=0; len(q1)=123; i=45
# Flow 45 status: fc12a65b-5a62-46e6-97df-9c22822bd98e: SUCCEEDED
# len(q0)=0; len(q1)=122; i=46
# Flow 46 status: 8241a1a9-bb53-4a66-b85d-c44b499a28e9: SUCCEEDED
# len(q0)=0; len(q1)=121; i=47
# Flow 47 status: d6a92a80-d68c-4aa5-8a9b-21260b6baefd: SUCCEEDED
# len(q0)=0; len(q1)=120; i=48
# Flow 48 status: 8c8324d2-3cde-4820-9a35-ddad7f916de2: SUCCEEDED
# len(q0)=0; len(q1)=119; i=49
# Flow 49 status: 2c990840-901f-46a7-a9b9-d3154467b3b7: SUCCEEDED
# len(q0)=0; len(q1)=118; i=50
# Flow 50 status: 42fb3dde-143d-48ce-a989-b131b098d686: SUCCEEDED
# len(q0)=0; len(q1)=117; i=51
# Flow 51 status: 3c2f5026-0881-4a2d-a8bc-2b7678e4c9dc: SUCCEEDED
# len(q0)=0; len(q1)=116; i=52
# Flow 52 status: 1399d5b7-1c11-42ab-9a65-041c6710c2da: SUCCEEDED
# len(q0)=0; len(q1)=115; i=53
# Flow 53 status: e2b7c67a-c087-4281-98d7-ddaaaf2836e6: SUCCEEDED
# len(q0)=0; len(q1)=114; i=54
# Flow 54 status: 86bade1b-9b22-45fe-ac1d-d7d169bf9434: SUCCEEDED
# len(q0)=0; len(q1)=113; i=55
# Flow 55 status: 703bed2b-e3aa-4e38-9031-0ffa2dbbacec: SUCCEEDED
# len(q0)=0; len(q1)=112; i=56
# Flow 56 status: 74abea36-253f-4a45-9314-5f5d25001da5: SUCCEEDED
# len(q0)=0; len(q1)=111; i=57
# Flow 57 status: 8b3eb625-a741-48a7-a104-bfdffb292b4f: SUCCEEDED
# len(q0)=0; len(q1)=110; i=58
# Flow 58 status: 5bfb28c4-9ebb-46f6-921d-ecc70bedb9a0: SUCCEEDED
# len(q0)=0; len(q1)=109; i=59
# Flow 59 status: 9c59713e-b100-400a-ab6e-58a47296dd12: SUCCEEDED
# len(q0)=0; len(q1)=108; i=60
# Flow 60 status: 91e31d7b-576d-4663-b42b-3d2c25695196: SUCCEEDED
# len(q0)=0; len(q1)=107; i=61
# Flow 61 status: 7d231456-7cdb-4173-8d0d-e196a689a762: SUCCEEDED
# len(q0)=0; len(q1)=106; i=62
# Flow 62 status: 2b19c83c-a8e2-4c32-a568-37c8446646ea: SUCCEEDED
# len(q0)=0; len(q1)=105; i=63
# Flow 63 status: 32b4c3db-fef6-4b55-a660-fecd55f12747: SUCCEEDED
# len(q0)=0; len(q1)=104; i=64
# Flow 64 status: 6bdb6e0b-a661-489a-acc0-78e1b8b90ede: SUCCEEDED
# len(q0)=0; len(q1)=103; i=65
# Flow 65 status: c6cff194-d37b-4b4e-8bf9-5bd38c8fa46e: SUCCEEDED
# len(q0)=0; len(q1)=102; i=66
# Flow 66 status: 0c808394-11dd-4c00-b70b-df877eecdfc4: SUCCEEDED
# len(q0)=0; len(q1)=101; i=67
# Flow 67 status: 3be91208-7eb0-47bd-85ee-f55496fc4e8f: SUCCEEDED
# len(q0)=0; len(q1)=100; i=68
# Flow 68 status: 2df2fb94-0b9c-4fd5-b80f-8c8ec5a0d975: SUCCEEDED
# len(q0)=0; len(q1)=99; i=69
# Flow 69 status: 1ea99140-e75d-49ce-a4d3-c0b20ecc21f4: SUCCEEDED
# len(q0)=0; len(q1)=98; i=70
# Flow 70 status: 9e76efaa-c992-41c2-a718-19ada52efa9d: SUCCEEDED
# len(q0)=0; len(q1)=97; i=71
# Flow 71 status: ed473e19-1991-43e4-a8e0-d80527d493a0: SUCCEEDED
# len(q0)=0; len(q1)=96; i=72
# Flow 72 status: 0961209c-48d9-4fd4-a988-e7cdb3bd84b6: SUCCEEDED
# len(q0)=0; len(q1)=95; i=73
# Flow 73 status: ff74c8dd-2bbf-4a74-9b5e-6bb5915532e3: SUCCEEDED
# len(q0)=0; len(q1)=94; i=74
# Flow 74 status: ec54c917-cfe8-422e-81b1-1eabb4f9d562: SUCCEEDED
# len(q0)=0; len(q1)=93; i=75
# Flow 75 status: d043b8d7-0c58-43e3-9310-b26529dbdc14: ACTIVE
# len(q0)=0; len(q1)=93; i=76
# Flow 76 status: 053aa79e-c4c0-4b95-a97d-844128cd007f: SUCCEEDED
# len(q0)=0; len(q1)=92; i=77
# Flow 77 status: e1d96c7e-bb68-4508-85b4-fccede42b96b: SUCCEEDED
# len(q0)=0; len(q1)=91; i=78
# Flow 78 status: 195200a9-0bfc-461b-a460-b68f4d982fae: SUCCEEDED
# len(q0)=0; len(q1)=90; i=79
# Flow 79 status: 8a800643-a802-47b8-b1d3-183b5b30cc97: ACTIVE
# len(q0)=0; len(q1)=90; i=80
# Flow 80 status: d51b11b1-9345-4a61-b159-779449499bf0: SUCCEEDED
# len(q0)=0; len(q1)=89; i=81
# Flow 81 status: ef8ae8ba-5c92-4482-8098-84a623e2c5c3: SUCCEEDED
# len(q0)=0; len(q1)=88; i=82
# Flow 82 status: 880154c7-8655-4346-a8cb-c3444e5c6688: SUCCEEDED
# len(q0)=0; len(q1)=87; i=83
# Flow 83 status: e01a3902-d3dc-4724-959a-6d97230d00a2: ACTIVE
# len(q0)=0; len(q1)=87; i=84
# Flow 84 status: 5e822d28-ab80-4a06-99dc-725c1da2d6e7: SUCCEEDED
# len(q0)=0; len(q1)=86; i=85
# Flow 85 status: 4ee280d2-e35e-4b5a-bb20-648dea3d028a: SUCCEEDED
# len(q0)=0; len(q1)=85; i=1
# Flow 1 status: 89e0a874-fd56-41d5-b5c3-5ef76c6b70b7: SUCCEEDED
# len(q0)=0; len(q1)=84; i=2
# Flow 2 status: 29170eed-3b35-4bd3-90e3-789732b0e9da: SUCCEEDED
# len(q0)=0; len(q1)=83; i=3
# Flow 3 status: 4ed2333b-8aa1-4dfe-9303-6f2b3201f65a: SUCCEEDED
# len(q0)=0; len(q1)=82; i=4
# Flow 4 status: 3982e79a-b23b-4552-b0fa-07c9f3eceb19: SUCCEEDED
# len(q0)=0; len(q1)=81; i=5
# Flow 5 status: 48afd98b-2108-4b30-8095-0637590f7546: SUCCEEDED
# len(q0)=0; len(q1)=80; i=6
# Flow 6 status: 14b08e89-f0eb-42c1-9a52-c22fa81c0158: SUCCEEDED
# len(q0)=0; len(q1)=79; i=7
# Flow 7 status: c682c7b9-a3ff-423b-8256-cd329b026f49: SUCCEEDED
# len(q0)=0; len(q1)=78; i=8
# Flow 8 status: 634771fd-9f43-4c1f-b756-c9ae3dd5ebf9: SUCCEEDED
# len(q0)=0; len(q1)=77; i=9
# Flow 9 status: 910abc27-b1f2-4d3d-ae68-beabb6fb581d: SUCCEEDED
# len(q0)=0; len(q1)=76; i=10
# Flow 10 status: 245fa4ae-5e14-41f4-8dc2-d18bbbb44bfa: SUCCEEDED
# len(q0)=0; len(q1)=75; i=11
# Flow 11 status: d39ce360-d9b3-4a55-9c1a-5ade3803bad5: SUCCEEDED
# len(q0)=0; len(q1)=74; i=12
# Flow 12 status: 9269e6af-ec3c-4c3d-a927-513bf3f63aa2: SUCCEEDED
# len(q0)=0; len(q1)=73; i=13
# Flow 13 status: 56fb77bf-aa44-4b38-ba9a-b17c0926eee8: SUCCEEDED
# len(q0)=0; len(q1)=72; i=14
# Flow 14 status: 2ffd893b-fdd1-44aa-b993-9a13452a311a: SUCCEEDED
# len(q0)=0; len(q1)=71; i=15
# Flow 15 status: 7c4d0a79-fb54-411f-809d-a87c175bfadb: SUCCEEDED
# len(q0)=0; len(q1)=70; i=16
# Flow 16 status: eaf65409-bab4-4e9b-844e-ab9b8f643f82: SUCCEEDED
# len(q0)=0; len(q1)=69; i=17
# Flow 17 status: 0939a9f7-35f8-42ab-835f-147e146b66f5: SUCCEEDED
# len(q0)=0; len(q1)=68; i=18
# Flow 18 status: 30761653-28af-4270-8dad-94027a81e760: SUCCEEDED
# len(q0)=0; len(q1)=67; i=19
# Flow 19 status: dc351606-8427-42ab-b9c8-cf5250ff28fe: SUCCEEDED
# len(q0)=0; len(q1)=66; i=20
# Flow 20 status: 4babba79-267e-40eb-9681-7142f8cd639b: SUCCEEDED
# len(q0)=0; len(q1)=65; i=21
# Flow 21 status: d920b9ad-97c4-4dc8-9bb7-40cf32145257: SUCCEEDED
# len(q0)=0; len(q1)=64; i=22
# Flow 22 status: 40101592-4ab3-47cf-9bf5-12a35b5567cd: SUCCEEDED
# len(q0)=0; len(q1)=63; i=23
# Flow 23 status: 223c1ba5-2e88-4c9e-8b5e-0fb38dc6bb28: SUCCEEDED
# len(q0)=0; len(q1)=62; i=24
# Flow 24 status: da7a0183-315a-4978-ae66-faf42d114a75: SUCCEEDED
# len(q0)=0; len(q1)=61; i=25
# Flow 25 status: a9b2f1bd-3bf1-4965-8462-8c66c5958b26: SUCCEEDED
# len(q0)=0; len(q1)=60; i=26
# Flow 26 status: 9f5db273-41a7-4a64-8701-a857c57ae05e: SUCCEEDED
# len(q0)=0; len(q1)=59; i=27
# Flow 27 status: e05f3279-b7a5-4547-a435-ad1a5c2f5d45: SUCCEEDED
# len(q0)=0; len(q1)=58; i=28
# Flow 28 status: a2ff714a-fce7-48e6-af49-d210ac6df1d6: SUCCEEDED
# len(q0)=0; len(q1)=57; i=29
# Flow 29 status: a78dcaf7-49c0-4f20-8c65-71caf0c785ae: SUCCEEDED
# len(q0)=0; len(q1)=56; i=30
# Flow 30 status: d9d33256-f3da-486f-b4fc-570337b250ad: SUCCEEDED
# len(q0)=0; len(q1)=55; i=31
# Flow 31 status: c5ac6131-2124-45cd-9e3d-a71310ce88a3: SUCCEEDED
# len(q0)=0; len(q1)=54; i=32
# Flow 32 status: 4df2b814-340a-46f4-b725-c378a289650c: SUCCEEDED
# len(q0)=0; len(q1)=53; i=33
# Flow 33 status: 367925b7-ae65-4959-983f-6b6c13a5dec8: SUCCEEDED
# len(q0)=0; len(q1)=52; i=34
# Flow 34 status: 5b67f163-3ad1-4e88-b75c-3e1cc5b3aeea: SUCCEEDED
# len(q0)=0; len(q1)=51; i=35
# Flow 35 status: 03574fd1-6c20-42ec-a24c-eed1314742f3: SUCCEEDED
# len(q0)=0; len(q1)=50; i=36
# Flow 36 status: 70dc0380-9e37-4427-8e1b-6ec8333443fa: SUCCEEDED
# len(q0)=0; len(q1)=49; i=37
# Flow 37 status: 3142d816-8cf7-450e-a362-006a5b72d84f: SUCCEEDED
# len(q0)=0; len(q1)=48; i=38
# Flow 38 status: d043b8d7-0c58-43e3-9310-b26529dbdc14: SUCCEEDED
# len(q0)=0; len(q1)=47; i=39
# Flow 39 status: 6fd64fc7-887d-41f1-9e38-2f8f5bd62501: SUCCEEDED
# len(q0)=0; len(q1)=46; i=40
# Flow 40 status: 8a800643-a802-47b8-b1d3-183b5b30cc97: SUCCEEDED
# len(q0)=0; len(q1)=45; i=41
# Flow 41 status: 931baa9f-945a-44c9-b877-21a666c85f79: SUCCEEDED
# len(q0)=0; len(q1)=44; i=42
# Flow 42 status: e01a3902-d3dc-4724-959a-6d97230d00a2: SUCCEEDED
# len(q0)=0; len(q1)=43; i=0
# Flow 0 status: 81fe19f0-08f2-422a-91d5-aaa86462cf99: SUCCEEDED
# len(q0)=0; len(q1)=42; i=1
# Flow 1 status: e0dc02ec-242c-4890-8550-83b141eb4c49: SUCCEEDED
# len(q0)=0; len(q1)=41; i=2
# Flow 2 status: e9c42de4-9d0d-48ee-abe9-d41e9a8d811d: SUCCEEDED
# len(q0)=0; len(q1)=40; i=3
# Flow 3 status: 2811cf79-842e-4a8e-b69c-53809f812377: SUCCEEDED
# len(q0)=0; len(q1)=39; i=4
# Flow 4 status: b786a84f-d2db-472f-91f4-7e2499d9fe30: SUCCEEDED
# len(q0)=0; len(q1)=38; i=5
# Flow 5 status: 0f5362ce-2d28-4ae2-a3f6-43bed5584efa: SUCCEEDED
# len(q0)=0; len(q1)=37; i=6
# Flow 6 status: 33ba5b6e-27bb-4082-8e59-e0c96ae426d6: SUCCEEDED
# len(q0)=0; len(q1)=36; i=7
# Flow 7 status: 1efe6dea-ca34-419b-bd48-7dcc805ade4a: SUCCEEDED
# len(q0)=0; len(q1)=35; i=8
# Flow 8 status: f80eaf67-60d4-4ed7-a64d-a08ce06ed01e: SUCCEEDED
# len(q0)=0; len(q1)=34; i=9
# Flow 9 status: 22cf92f3-30ce-4eba-97ad-def9a2e29a1d: SUCCEEDED
# len(q0)=0; len(q1)=33; i=10
# Flow 10 status: 616840bc-a55f-412a-96f7-c66050f18099: SUCCEEDED
# len(q0)=0; len(q1)=32; i=11
# Flow 11 status: 1a1375c5-fc97-47fe-b2b7-7f196b050113: SUCCEEDED
# len(q0)=0; len(q1)=31; i=12
# Flow 12 status: c7a5d637-fb6f-4faf-9ebc-1ff3780df49a: SUCCEEDED
# len(q0)=0; len(q1)=30; i=13
# Flow 13 status: eea547c5-70e6-4b59-be5c-b9f813f2ae75: SUCCEEDED
# len(q0)=0; len(q1)=29; i=14
# Flow 14 status: e5c38ea3-b3bf-480c-a23e-8f242e563529: SUCCEEDED
# len(q0)=0; len(q1)=28; i=15
# Flow 15 status: e2bf85d5-e4f9-41b3-8069-b2af7b29c845: SUCCEEDED
# len(q0)=0; len(q1)=27; i=16
# Flow 16 status: 4ca47b57-819a-44f5-832b-fc9e543c0d41: SUCCEEDED
# len(q0)=0; len(q1)=26; i=17
# Flow 17 status: cda2f556-05d1-4adf-95d8-070f82096253: SUCCEEDED
# len(q0)=0; len(q1)=25; i=18
# Flow 18 status: e6045272-95d0-4149-b6a8-53db46cbccaf: SUCCEEDED
# len(q0)=0; len(q1)=24; i=19
# Flow 19 status: f87ec444-f848-4f4b-9d3e-7508f2c03118: SUCCEEDED
# len(q0)=0; len(q1)=23; i=20
# Flow 20 status: 2014c77a-f572-4b93-ae44-11e00b21632c: SUCCEEDED
# len(q0)=0; len(q1)=22; i=21
# Flow 21 status: cdc35997-8999-420e-8a3a-aabc5fd3b1d1: SUCCEEDED
# len(q0)=0; len(q1)=21; i=1
# Flow 1 status: 17266567-c5c0-43e3-b8fb-309578242b6f: SUCCEEDED
# len(q0)=0; len(q1)=20; i=2
# Flow 2 status: ee43b122-75b7-4fa3-a4af-805b3230bf5e: SUCCEEDED
# len(q0)=0; len(q1)=19; i=3
# Flow 3 status: b4f2945b-7fca-4a5b-b4ab-350ceaae515f: SUCCEEDED
# len(q0)=0; len(q1)=18; i=4
# Flow 4 status: e4980640-a04b-4222-aae9-74fff34518e5: SUCCEEDED
# len(q0)=0; len(q1)=17; i=5
# Flow 5 status: e8bb5f3b-46e6-454d-a80f-6a8f8edd00b5: SUCCEEDED
# len(q0)=0; len(q1)=16; i=6
# Flow 6 status: 50eb8da0-60ce-4369-8c1e-0859f309bee8: SUCCEEDED
# len(q0)=0; len(q1)=15; i=7
# Flow 7 status: 0f4bbb2d-5707-44d2-9f44-335e9502f50f: SUCCEEDED
# len(q0)=0; len(q1)=14; i=8
# Flow 8 status: 333892dd-d4df-4f51-918f-8a13f6e3d3ae: SUCCEEDED
# len(q0)=0; len(q1)=13; i=9
# Flow 9 status: f1a97d0b-959a-4aee-bd42-d69d76e625e5: SUCCEEDED
# len(q0)=0; len(q1)=12; i=10
# Flow 10 status: 009fd2d6-14ce-4bb2-af23-50fd8213ec69: SUCCEEDED
# len(q0)=0; len(q1)=11; i=0
# Flow 0 status: 06493b02-2ced-4640-93e6-b478b145276f: SUCCEEDED
# len(q0)=0; len(q1)=10; i=1
# Flow 1 status: 8c45f9dc-ee92-49d8-b181-b05bb20c1712: SUCCEEDED
# len(q0)=0; len(q1)=9; i=2
# Flow 2 status: 7323937e-a37c-4731-9700-126d284a6b2d: SUCCEEDED
# len(q0)=0; len(q1)=8; i=3
# Flow 3 status: 32e91790-a522-4bba-a5b7-7b5171b191cc: SUCCEEDED
# len(q0)=0; len(q1)=7; i=4
# Flow 4 status: a585da8d-0509-45e8-8b0f-2a7d35791bbe: SUCCEEDED
# len(q0)=0; len(q1)=6; i=5
# Flow 5 status: 6aecb044-8bc3-4caa-baae-8c2087280deb: SUCCEEDED
# len(q0)=0; len(q1)=5; i=1
# Flow 1 status: 75c5e35f-838b-4919-b32b-0d564b72828a: SUCCEEDED
# len(q0)=0; len(q1)=4; i=2
# Flow 2 status: 118ff4a9-aee1-4d19-9b80-35b77d65809c: SUCCEEDED
# len(q0)=0; len(q1)=3; i=0
# Flow 0 status: c9148677-9d26-431a-8b74-f4f847eb034a: SUCCEEDED
# len(q0)=0; len(q1)=2; i=1
# Flow 1 status: 2af04b18-0c27-4fef-a451-70a4194cf7bc: SUCCEEDED
# len(q0)=0; len(q1)=1; i=0
# Flow 0 status: aad174dd-bad3-48e8-aeb7-7be20fe9b98f: SUCCEEDED

# %%
print(flow_scope)

# %%
for flow_action in q1:
    flows_client.flow_action_cancel(flow_id, flow_scope, flow_action['action_id'])

# %%
#flows_client.flow_action_cancel(flow_id, flow_scope, '5e948f48-c3c3-4328-8d37-b5d1bc82df4c')

# %%
#for ga_flow_action_id in ga_flow_actions.keys():
#    flows_client.flow_action_cancel(flow_id, flow_scope, ga_flow_action_id)

# %%
#st = flows_client.flow_action_status(flow_id, flow_scope, '08925f04-569f-11e7-bef8-22000b9a448b')
#print(st['status'])
